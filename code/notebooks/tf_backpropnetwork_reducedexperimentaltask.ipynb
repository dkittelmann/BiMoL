# %% [markdown]
# imports

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2024-10-29 10:25:14.524106: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Helper and preprocessing functions

# %%
def tf_scale_imgs(imgs, scale_factor):
    return imgs * scale_factor + 0.5 * (1 - scale_factor) * tf.ones(imgs.shape)


def tf_scale_labels(labels, scale_factor):
    return labels * scale_factor + 0.5 * (1 - scale_factor) * tf.ones(labels.shape)


def tf_f_inv(x, act_fn):
    """ (activation_size, batch_size) """
    if act_fn == "LINEAR":
        m = x
    elif act_fn == "TANH":
        num = tf.ones_like(x) + x
        div = tf.ones_like(x) - x + 1e-7
        m = 0.5 * tf.math.log(num / div)
    elif act_fn == "LOGSIG":
        div = tf.ones_like(x) - x + 1e-7
        m = tf.math.log((x / div) + 1e-7)
    else:
        raise ValueError(f"{act_fn} not supported")
    return m


def img_preproc(x, y, dtype=tf.float32): # add: tf.image.resize(image, [28,28])
  """Cast input image to a certain tf dtype and normalize them between 0 and 1."""
  x = tf.cast(x, dtype) / 255.
  #x = tf_scale_imgs(x, cf.img_scale)
  #y = tf_scale_labels(y, cf.label_scale)
  #x = tf_f_inv(x, "TANH")
  #y = tf.one_hot(y, depth=10)
  return x, y


def flatten(x, y):
  #flattens a video image series (or batch of images) to (n_batch, n_steps, 1) d.
  shape = tf.shape(x)
  if len(shape) == 5: # hack, determining if it's a video or not
    x = tf.reshape(x, [shape[0], shape[1], -1])
  elif len(shape) == 4:
    x = tf.reshape(x, [shape[0], -1])
  return x, y

def augment_images(batch_images, batch_labels):
    """
    Applies data augmentation on a batch of images without TensorFlow Addons.
    
    Parameters:
    batch_images: Tensor of shape (n_batch, 96, 96, 3)
    
    Returns:
    Augmented batch of images.
    """
    # Random horizontal flip
    augmented_images = tf.image.random_flip_left_right(batch_images)
    
    # Random brightness adjustment
    augmented_images = tf.image.random_brightness(augmented_images, max_delta=0.1)
    
    # Random contrast adjustment
    augmented_images = tf.image.random_contrast(augmented_images, lower=0.9, upper=1.1)
    
    # Random saturation adjustment
    augmented_images = tf.image.random_saturation(augmented_images, lower=0.9, upper=1.1)
    
    # Random hue adjustment
    augmented_images = tf.image.random_hue(augmented_images, max_delta=0.05)
    
    # Clipping to ensure pixel values are valid after transformations
    augmented_images = tf.clip_by_value(augmented_images, 0.0, 1.0)
    
    return augmented_images, batch_labels

resultspath = '/Users/denisekittelmann/Documents/Python/BiMoL/results/bp_ann/model_checkpoint_reduced_{epoch:02d}_{accuracy:.2f}.keras'

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath= resultspath,  
    monitor='accuracy',         # The metric to monitor for saving (e.g., 'val_loss', 'val_accuracy')
    save_best_only=True,        # Save only the best model 
    save_weights_only=False,    # False = Save the entire model; True = only save weights
    mode='max',                 # Set to 'min' for metrics like loss and 'max' for metrics like accuracy
    save_freq='epoch',          # Frequency of saving, e.g., epoch or batch 
    verbose=1                   # Print when saving a model
)

# %% [markdown]
# Load the data

# %%
# Create a leading and trailing dataset with tensorflow

img_dir_lead = '/Users/denisekittelmann/Documents/Python/BiMoL/data/Leading/'
img_dir_trail = '/Users/denisekittelmann/Documents/Python/BiMoL/data/Trailing/'
img_dir_test_lead = '/Users/denisekittelmann/Documents/Python/BiMoL/data/Test/Test_Leading/'
img_dir_test_trail = '/Users/denisekittelmann/Documents/Python/BiMoL/data/Test/Test_Trailing/'
class_names_L = ['barn', 'beach', 'cave', 'library', 'restaurant']
class_names_T = ['castle', 'Church', 'conference_room', 'forest'] # changed the order 
batch_size = None # adjust if needed, e.g., 32
image_size = (28,28)
validation_split = 0.1
seed = 123

# %%
# Create a leading and trailing dataset with tensorflow

img_dir_lead = '/scratch/guetlid95/datasets/mcdermott_2024/Stimuli_2/Leading/'
img_dir_trail = '/scratch/guetlid95/datasets/mcdermott_2024/Stimuli_2/Trailing/' 
img_dir_test_lead = '/scratch/guetlid95/datasets/mcdermott_2024/Stimuli_2/Test/Test_Leading/' 
img_dir_test_trail = '/scratch/guetlid95/datasets/mcdermott_2024/Stimuli_2/Test/Test_Trailing/' 
class_names_L = ['barn', 'beach', 'cave', 'library', 'restaurant']
class_names_T = ['castle', 'Church', 'conference_room', 'forest'] # changed the order 
batch_size = 32
image_size = (28,28)
validation_split = 0.1
seed = 123

# %%
# Create a dict that assigns the correct labels for each leading-trailing img pair

"""
L1 = barn = label 0 
L2 = beach = label 1
L3 = library = label 3
L4 = restaurant = label 4 
L5 = cave = label 2

T6 = Church = label 1   
T7 = conference room = label 2
T8 = castle = label 0   
T9 = forest = label 3

MAPPING:

L1 -> T6 = 0.75 -> (0,1) 
L1 -> T7 = 0.25 -> (0,2)
L1 -> T8 = 0 -> (0,0)
L1 -> T9 = 0 -> (0,3)

L2 -> T6 = 0.75 -> (1,1) 
L2 -> T7 = 0.25 -> (1,2)
L2 -> T8 = 0 -> (1,0)
L2 -> T9 = 0 -> (1,3)

L3 -> T6 = 0 -> (3,1) 
L3 -> T7 = 0 -> (3,2)
L3 -> T8 = 0.5 -> (3,0)
L3 -> T9 = 0.5 -> (3,3)

L4 -> T6 = 0.25 -> (4,1) 
L4 -> T7 = 0.75 -> (4,2)
L4 -> T8 = 0 -> (4,0)
L4 -> T9 = 0 -> (4,3)

L5 -> T6 = 0.25 -> (2,1) 
L5 -> T7 = 0.75 -> (2,2)
L5 -> T8 = 0 -> (2,0)
L5 -> T9 = 0 -> (2,3)

"""


label_dict = {
    (0, 1): 0.0,
    (0, 2): 0.75,
    (0, 0): 0.25,
    (0, 3): 0.25,
    
    (1, 1): 0.0,
    (1, 2): 0.75,
    (1, 0): 0.25,
    (1, 3): 0.25,
    
    (3, 1): 0.75,
    (3, 2): 0.75,
    (3, 0): 0.50,
    (3, 3): 0.50,
    
    (4, 1): 0.75,
    (4, 2): 0.0,
    (4, 0): 0.25,
    (4, 3): 0.25,
    
    (2, 1): 0.75, 
    (2, 2): 0.0,
    (2, 0): 0.25,
    (2, 3): 0.25
}

# %%
# Generate image pairs 
def img_sequence(img_t1, img_t2, label_t1, label_t2, label_dict): 
    """This function stacks two images to construct an image pair and assigns a single label based on the label dictionary."""
    
    img_t1 = tf.cast(img_t1, dtype=tf.float32)
    img_t2 = tf.cast(img_t2, dtype=tf.float32)
    
    x = tf.concat([img_t1, img_t2], axis=0) 

    key_t1 = int(label_t1.numpy())
    key_t2 = int(label_t2.numpy())
    
    if (key_t1, key_t2) in label_dict:
        label = label_dict[(key_t1, key_t2)]
        #print(f"Label value found: {label}")
    else:
        print(f"Label pair {(key_t1, key_t2)} not found.")

    y = tf.cast(tf.random.uniform([]) < label, tf.float32)
    y = tf.expand_dims(y, axis=0)  
    
    return x,y

# %%
def generate_dataset(img_dirt1, img_dirt2, class_namest1, class_namest2, label_dict, image_size = None, seed = None, shuffle=False):       
    
    
    data_t1 = tf.keras.preprocessing.image_dataset_from_directory(
        img_dirt1, 
        label_mode = 'int',
        class_names= class_namest1,
        batch_size = None,
        color_mode = 'rgb',
        image_size = image_size, 
        #shuffle = True, 
        seed = seed
        )

    data_t2 = tf.keras.preprocessing.image_dataset_from_directory(
        img_dirt2, 
        label_mode = 'int',
        class_names= class_namest2,
        batch_size = None,
        color_mode = 'rgb', 
        image_size = image_size, 
        #shuffle = True, 
        seed = seed
    )
    
    if shuffle:
        data_t1.shuffle(99999)
        data_t2.shuffle(99999)
    
    # iterate through shuffled leading and trailing datasets
    leading = iter(data_t1)
    trailing = iter(data_t2) 
              
    while True:
        try:
            # Retrieve single samples
            img_t1, label_t1 = next(leading)
            img_t2, label_t2 = next(trailing)

            # Generate x, y pairs for single samples
            x, y = img_sequence(img_t1, img_t2, label_t1, label_t2, label_dict)
            yield x, y
            
        except StopIteration:
            # Break the loop if no more samples
            break

# %%
from collections import Counter

def check_transition_balance(dataset):
    transition_counts = Counter()
    
    # Use as_numpy_iterator to extract data from the dataset
    for image, label in dataset.as_numpy_iterator():
        # Convert label to a scalar value if it's in a numpy array form
        transition_counts[label[0]] += 1  # Assuming label is a scalar or one-element array
    
    print("Transition frequencies:")
    for transition, count in transition_counts.items():
        print(f"Transition {transition}: {count} occurrences")

# %%
# Build the validation dataset 

seed = 123

val_dataset = tf.data.Dataset.from_generator(
    lambda: generate_dataset(img_dir_test_lead, img_dir_test_trail, class_names_L, class_names_T, label_dict, image_size = (28,28), seed = seed),
    output_signature=(
        tf.TensorSpec(shape=(56, 28, 3), dtype=tf.float32),  # shape of x 
        tf.TensorSpec(shape=(1), dtype=tf.float32)  # shape of y 
    )
) 

print(val_dataset)
# Out:
# <_FlatMapDataset element_spec=(TensorSpec(shape=(56, 28, 3), dtype=tf.float32, name=None), TensorSpec(shape=(1,), dtype=tf.float32, name=None))>

# %% [markdown]
# train the network

# %%
# define the model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=6, activation="sigmoid"), # 
    tf.keras.layers.Dense(units=4, activation="sigmoid"),  # Second layer 2
    tf.keras.layers.Dense(units=1, activation="sigmoid")  # Output layer
])

model.build([None,4704]) 
model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=1e-2),
              metrics=["accuracy"],
              loss="BinaryCrossentropy",  # "CategoricalCrossentropy" "MeanSquaredError" 
              )

# save model before training
#model.save('/Users/denisekittelmann/Documents/Python/BiMoL/results/bp_ann/final_model_bp_lr_untrained.keras') # add lr

# evaluate accuracy and train model
loss, accuracy = model.evaluate(val_dataset.batch(512).map(img_preproc).map(flatten)) 
print(f"Accuracy before training: {accuracy}")


n_epochs = 1000

train_acc = []
val_acc = []
train_loss = []
val_loss = []


for i in range(n_epochs): 
    
    print(f"Epoch {i + 1}/{n_epochs}") 
    train_dataset = tf.data.Dataset.from_generator(
        lambda: generate_dataset(img_dir_lead, img_dir_trail, class_names_L, class_names_T, label_dict, image_size = (28,28), seed = i, shuffle =True), 
        output_signature=(
            tf.TensorSpec(shape=(56, 28, 3), dtype=tf.float32),  # shape of x 
            tf.TensorSpec(shape=(1), dtype=tf.float32)  # shape of y 
        )
    )  
    
    check_transition_balance(train_dataset)
    
    history = model.fit(train_dataset.shuffle(99999).batch(512).map(img_preproc).map(augment_images).map(flatten), 
            validation_data=val_dataset.batch(512).map(img_preproc).map(flatten),
            callbacks=[checkpoint_callback]) 
    
    train_acc.extend(history.history['accuracy'])
    val_acc.extend(history.history['val_accuracy'])
    train_loss.extend(history.history['loss'])
    val_loss.extend(history.history['val_loss'])

loss, accuracy = model.evaluate(val_dataset.batch(512).map(img_preproc).map(flatten)) 
print(f"Accuracy after training: {accuracy}")

#model.save('/Users/denisekittelmann/Documents/Python/BiMoL/results/bp_ann/final_model_bp_lr_trained.keras') # add lr
# Out:
# Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6556 - loss: 0.6551
# Accuracy before training: 0.6555555462837219
# Epoch 1/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1076 occurrences
# Transition 1.0: 540 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 5s 39ms/step - accuracy: 0.6628 - loss: 0.6498Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 0.6652 - loss: 0.6478 - val_accuracy: 0.7000 - val_loss: 0.6270
# Epoch 2/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1057 occurrences
# Transition 1.0: 559 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 37ms/step - accuracy: 0.6709 - loss: 0.6404Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.6699 - loss: 0.6408 - val_accuracy: 0.6778 - val_loss: 0.6366
# Epoch 3/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1079 occurrences
# Transition 1.0: 537 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 36ms/step - accuracy: 0.6586 - loss: 0.6456Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 241ms/step - accuracy: 0.6615 - loss: 0.6442 - val_accuracy: 0.6778 - val_loss: 0.6360
# Epoch 4/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1088 occurrences
# Transition 1.0: 528 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 36ms/step - accuracy: 0.6581 - loss: 0.6455Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 211ms/step - accuracy: 0.6602 - loss: 0.6445 - val_accuracy: 0.6722 - val_loss: 0.6383
# Epoch 5/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1070 occurrences
# Transition 1.0: 546 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 4s 48ms/step - accuracy: 0.6569 - loss: 0.6458Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.6592 - loss: 0.6446 - val_accuracy: 0.6667 - val_loss: 0.6406
# Epoch 6/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1065 occurrences
# Transition 1.0: 551 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 39ms/step - accuracy: 0.6705 - loss: 0.6386Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - accuracy: 0.6706 - loss: 0.6385 - val_accuracy: 0.6111 - val_loss: 0.6687
# Epoch 7/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 563 occurrences
# Transition 0.0: 1053 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 36ms/step - accuracy: 0.6631 - loss: 0.6420Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.6637 - loss: 0.6416 - val_accuracy: 0.7056 - val_loss: 0.6195
# Epoch 8/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 509 occurrences
# Transition 0.0: 1107 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 38ms/step - accuracy: 0.6756 - loss: 0.6351Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - accuracy: 0.6734 - loss: 0.6362 - val_accuracy: 0.6722 - val_loss: 0.6365
# Epoch 9/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 518 occurrences
# Transition 0.0: 1098 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 38ms/step - accuracy: 0.6795 - loss: 0.6326Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.6795 - loss: 0.6325 - val_accuracy: 0.6722 - val_loss: 0.6360
# Epoch 10/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 525 occurrences
# Transition 0.0: 1091 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 40ms/step - accuracy: 0.6573 - loss: 0.6441Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - accuracy: 0.6583 - loss: 0.6436 - val_accuracy: 0.6500 - val_loss: 0.6480
# Epoch 11/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 548 occurrences
# Transition 0.0: 1068 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 43ms/step - accuracy: 0.6722 - loss: 0.6356Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - accuracy: 0.6751 - loss: 0.6340 - val_accuracy: 0.6667 - val_loss: 0.6384
# Epoch 12/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1097 occurrences
# Transition 1.0: 519 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 37ms/step - accuracy: 0.6815 - loss: 0.6300Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.6733 - loss: 0.6347 - val_accuracy: 0.7611 - val_loss: 0.5840
# Epoch 13/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 547 occurrences
# Transition 0.0: 1069 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 35ms/step - accuracy: 0.6747 - loss: 0.6335Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.6712 - loss: 0.6355 - val_accuracy: 0.6389 - val_loss: 0.6541
# Epoch 14/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1070 occurrences
# Transition 1.0: 546 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 37ms/step - accuracy: 0.6380 - loss: 0.6546Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 168ms/step - accuracy: 0.6464 - loss: 0.6496 - val_accuracy: 0.6611 - val_loss: 0.6410
# Epoch 15/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1072 occurrences
# Transition 1.0: 544 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 35ms/step - accuracy: 0.6611 - loss: 0.6410Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - accuracy: 0.6638 - loss: 0.6394 - val_accuracy: 0.7222 - val_loss: 0.6045
# Epoch 16/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1066 occurrences
# Transition 1.0: 550 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 37ms/step - accuracy: 0.6647 - loss: 0.6387Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - accuracy: 0.6699 - loss: 0.6356 - val_accuracy: 0.6889 - val_loss: 0.6240
# Epoch 17/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 521 occurrences
# Transition 0.0: 1095 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 42ms/step - accuracy: 0.6577 - loss: 0.6428Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.6624 - loss: 0.6399 - val_accuracy: 0.6611 - val_loss: 0.6407
# Epoch 18/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1065 occurrences
# Transition 1.0: 551 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 36ms/step - accuracy: 0.6722 - loss: 0.6338Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - accuracy: 0.6714 - loss: 0.6343 - val_accuracy: 0.6889 - val_loss: 0.6234
# Epoch 19/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1090 occurrences
# Transition 1.0: 526 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 37ms/step - accuracy: 0.6569 - loss: 0.6431Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - accuracy: 0.6595 - loss: 0.6415 - val_accuracy: 0.6556 - val_loss: 0.6440
# Epoch 20/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 543 occurrences
# Transition 0.0: 1073 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 4s 40ms/step - accuracy: 0.6924 - loss: 0.6209Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - accuracy: 0.6884 - loss: 0.6234 - val_accuracy: 0.7333 - val_loss: 0.5949
# Epoch 21/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 547 occurrences
# Transition 0.0: 1069 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 46ms/step - accuracy: 0.6705 - loss: 0.6345Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 203ms/step - accuracy: 0.6770 - loss: 0.6303 - val_accuracy: 0.6556 - val_loss: 0.6439
# Epoch 22/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1095 occurrences
# Transition 1.0: 521 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 38ms/step - accuracy: 0.6710 - loss: 0.6341Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - accuracy: 0.6704 - loss: 0.6345 - val_accuracy: 0.6722 - val_loss: 0.6332
# Epoch 23/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1096 occurrences
# Transition 1.0: 520 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 4s 35ms/step - accuracy: 0.6811 - loss: 0.6275Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 177ms/step - accuracy: 0.6787 - loss: 0.6290 - val_accuracy: 0.6889 - val_loss: 0.6223
# Epoch 24/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1092 occurrences
# Transition 1.0: 524 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 44ms/step - accuracy: 0.6642 - loss: 0.6383Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step - accuracy: 0.6658 - loss: 0.6372 - val_accuracy: 0.6944 - val_loss: 0.6185
# Epoch 25/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1096 occurrences
# Transition 1.0: 520 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 37ms/step - accuracy: 0.6595 - loss: 0.6413Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.6615 - loss: 0.6400 - val_accuracy: 0.7111 - val_loss: 0.6074
# Epoch 26/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 531 occurrences
# Transition 0.0: 1085 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       2/Unknown 3s 98ms/step - accuracy: 0.6753 - loss: 0.6310Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.6700 - loss: 0.6344 - val_accuracy: 0.6333 - val_loss: 0.6586
# Epoch 27/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1080 occurrences
# Transition 1.0: 536 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 4s 46ms/step - accuracy: 0.6756 - loss: 0.6307Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 252ms/step - accuracy: 0.6781 - loss: 0.6290 - val_accuracy: 0.5833 - val_loss: 0.6920
# Epoch 28/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1086 occurrences
# Transition 1.0: 530 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 36ms/step - accuracy: 0.6543 - loss: 0.6448Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - accuracy: 0.6592 - loss: 0.6416 - val_accuracy: 0.6333 - val_loss: 0.6589
# Epoch 29/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1080 occurrences
# Transition 1.0: 536 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 38ms/step - accuracy: 0.6627 - loss: 0.6393Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.6622 - loss: 0.6396 - val_accuracy: 0.6778 - val_loss: 0.6291
# Epoch 30/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1112 occurrences
# Transition 1.0: 504 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 39ms/step - accuracy: 0.6679 - loss: 0.6358Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - accuracy: 0.6680 - loss: 0.6356 - val_accuracy: 0.6556 - val_loss: 0.6440
# Epoch 31/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1103 occurrences
# Transition 1.0: 513 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 39ms/step - accuracy: 0.6821 - loss: 0.6261Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - accuracy: 0.6818 - loss: 0.6263 - val_accuracy: 0.6778 - val_loss: 0.6290
# Epoch 32/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1109 occurrences
# Transition 1.0: 507 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 36ms/step - accuracy: 0.6730 - loss: 0.6323Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - accuracy: 0.6733 - loss: 0.6320 - val_accuracy: 0.6056 - val_loss: 0.6782
# Epoch 33/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 555 occurrences
# Transition 0.0: 1061 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 36ms/step - accuracy: 0.6751 - loss: 0.6308Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - accuracy: 0.6707 - loss: 0.6338 - val_accuracy: 0.7000 - val_loss: 0.6137
# Epoch 34/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1067 occurrences
# Transition 1.0: 549 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 34ms/step - accuracy: 0.6817 - loss: 0.6262Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 162ms/step - accuracy: 0.6796 - loss: 0.6276 - val_accuracy: 0.6667 - val_loss: 0.6365
# Epoch 35/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1047 occurrences
# Transition 1.0: 569 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 43ms/step - accuracy: 0.6742 - loss: 0.6313Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - accuracy: 0.6768 - loss: 0.6295 - val_accuracy: 0.7000 - val_loss: 0.6134
# Epoch 36/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 538 occurrences
# Transition 0.0: 1078 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 35ms/step - accuracy: 0.6654 - loss: 0.6374Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 166ms/step - accuracy: 0.6638 - loss: 0.6385 - val_accuracy: 0.6500 - val_loss: 0.6481
# Epoch 37/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1093 occurrences
# Transition 1.0: 523 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 45ms/step - accuracy: 0.6610 - loss: 0.6404Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - accuracy: 0.6634 - loss: 0.6387 - val_accuracy: 0.6722 - val_loss: 0.6326
# Epoch 38/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 538 occurrences
# Transition 0.0: 1078 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 34ms/step - accuracy: 0.6649 - loss: 0.6377Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - accuracy: 0.6663 - loss: 0.6368 - val_accuracy: 0.7167 - val_loss: 0.6015
# Epoch 39/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 527 occurrences
# Transition 0.0: 1089 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       2/Unknown 3s 51ms/step - accuracy: 0.7007 - loss: 0.6125Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 185ms/step - accuracy: 0.6870 - loss: 0.6221 - val_accuracy: 0.7389 - val_loss: 0.5858
# Epoch 40/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1066 occurrences
# Transition 1.0: 550 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 38ms/step - accuracy: 0.6557 - loss: 0.6438Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 174ms/step - accuracy: 0.6543 - loss: 0.6446 - val_accuracy: 0.6667 - val_loss: 0.6350
# Epoch 41/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1085 occurrences
# Transition 1.0: 531 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 44ms/step - accuracy: 0.6776 - loss: 0.6268Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 231ms/step - accuracy: 0.6732 - loss: 0.6297 - val_accuracy: 0.6944 - val_loss: 0.6139
# Epoch 42/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 530 occurrences
# Transition 0.0: 1086 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 35ms/step - accuracy: 0.6828 - loss: 0.6230Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.6795 - loss: 0.6251 - val_accuracy: 0.6278 - val_loss: 0.6595
# Epoch 43/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1093 occurrences
# Transition 1.0: 523 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       4/Unknown 3s 36ms/step - accuracy: 0.6752 - loss: 0.6269Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 240ms/step - accuracy: 0.6765 - loss: 0.6260 - val_accuracy: 0.6611 - val_loss: 0.6361
# Epoch 44/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 535 occurrences
# Transition 0.0: 1081 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 42ms/step - accuracy: 0.6634 - loss: 0.6341Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.6622 - loss: 0.6347 - val_accuracy: 0.6056 - val_loss: 0.6710
# Epoch 45/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 546 occurrences
# Transition 0.0: 1070 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 4s 40ms/step - accuracy: 0.6623 - loss: 0.6340Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.6630 - loss: 0.6334 - val_accuracy: 0.6944 - val_loss: 0.6109
# Epoch 46/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 543 occurrences
# Transition 0.0: 1073 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       2/Unknown 3s 50ms/step - accuracy: 0.6929 - loss: 0.6134Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 218ms/step - accuracy: 0.6905 - loss: 0.6154 - val_accuracy: 0.6944 - val_loss: 0.6111
# Epoch 47/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1093 occurrences
# Transition 1.0: 523 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 41ms/step - accuracy: 0.6633 - loss: 0.6328Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - accuracy: 0.6663 - loss: 0.6308 - val_accuracy: 0.7056 - val_loss: 0.6043
# Epoch 48/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 559 occurrences
# Transition 0.0: 1057 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 35ms/step - accuracy: 0.6660 - loss: 0.6316Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.6652 - loss: 0.6321 - val_accuracy: 0.7056 - val_loss: 0.6018
# Epoch 49/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1082 occurrences
# Transition 1.0: 534 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 37ms/step - accuracy: 0.6975 - loss: 0.6111Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - accuracy: 0.6932 - loss: 0.6138 - val_accuracy: 0.6500 - val_loss: 0.6437
# Epoch 50/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 536 occurrences
# Transition 0.0: 1080 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 36ms/step - accuracy: 0.6629 - loss: 0.6319Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 202ms/step - accuracy: 0.6613 - loss: 0.6332 - val_accuracy: 0.7111 - val_loss: 0.5991
# Epoch 51/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 547 occurrences
# Transition 0.0: 1069 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 76ms/step - accuracy: 0.6736 - loss: 0.6255Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - accuracy: 0.6727 - loss: 0.6259 - val_accuracy: 0.6778 - val_loss: 0.6229
# Epoch 52/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1070 occurrences
# Transition 1.0: 546 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 36ms/step - accuracy: 0.6672 - loss: 0.6292Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - accuracy: 0.6679 - loss: 0.6288 - val_accuracy: 0.6944 - val_loss: 0.6098
# Epoch 53/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1069 occurrences
# Transition 1.0: 547 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 36ms/step - accuracy: 0.6681 - loss: 0.6276Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.6674 - loss: 0.6281 - val_accuracy: 0.6667 - val_loss: 0.6295
# Epoch 54/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 548 occurrences
# Transition 0.0: 1068 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 78ms/step - accuracy: 0.6622 - loss: 0.6307 Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 214ms/step - accuracy: 0.6639 - loss: 0.6297 - val_accuracy: 0.6333 - val_loss: 0.6488
# Epoch 55/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 531 occurrences
# Transition 0.0: 1085 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 38ms/step - accuracy: 0.6642 - loss: 0.6298Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - accuracy: 0.6651 - loss: 0.6291 - val_accuracy: 0.6389 - val_loss: 0.6413
# Epoch 56/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 524 occurrences
# Transition 0.0: 1092 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 40ms/step - accuracy: 0.6700 - loss: 0.6239Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - accuracy: 0.6691 - loss: 0.6247 - val_accuracy: 0.7056 - val_loss: 0.6022
# Epoch 57/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1076 occurrences
# Transition 1.0: 540 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 35ms/step - accuracy: 0.6659 - loss: 0.6268Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.6656 - loss: 0.6271 - val_accuracy: 0.6444 - val_loss: 0.6402
# Epoch 58/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 527 occurrences
# Transition 0.0: 1089 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 49ms/step - accuracy: 0.6624 - loss: 0.6294Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.6653 - loss: 0.6274 - val_accuracy: 0.6889 - val_loss: 0.6066
# Epoch 59/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1094 occurrences
# Transition 1.0: 522 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 35ms/step - accuracy: 0.6623 - loss: 0.6280Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.6627 - loss: 0.6277 - val_accuracy: 0.6944 - val_loss: 0.6077
# Epoch 60/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1090 occurrences
# Transition 1.0: 526 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 36ms/step - accuracy: 0.6660 - loss: 0.6264Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 266ms/step - accuracy: 0.6630 - loss: 0.6282 - val_accuracy: 0.6667 - val_loss: 0.6252
# Epoch 61/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1111 occurrences
# Transition 1.0: 505 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 39ms/step - accuracy: 0.6832 - loss: 0.6136Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 189ms/step - accuracy: 0.6814 - loss: 0.6148 - val_accuracy: 0.6889 - val_loss: 0.6019
# Epoch 62/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1090 occurrences
# Transition 1.0: 526 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 39ms/step - accuracy: 0.6711 - loss: 0.6220Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - accuracy: 0.6690 - loss: 0.6230 - val_accuracy: 0.6722 - val_loss: 0.6181
# Epoch 63/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1077 occurrences
# Transition 1.0: 539 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 42ms/step - accuracy: 0.6670 - loss: 0.6248Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 203ms/step - accuracy: 0.6702 - loss: 0.6224 - val_accuracy: 0.6778 - val_loss: 0.6136
# Epoch 64/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1093 occurrences
# Transition 1.0: 523 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 45ms/step - accuracy: 0.6821 - loss: 0.6144Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - accuracy: 0.6793 - loss: 0.6160 - val_accuracy: 0.6444 - val_loss: 0.6319
# Epoch 65/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1105 occurrences
# Transition 1.0: 511 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 44ms/step - accuracy: 0.6804 - loss: 0.6126Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - accuracy: 0.6786 - loss: 0.6138 - val_accuracy: 0.6778 - val_loss: 0.6134
# Epoch 66/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1063 occurrences
# Transition 1.0: 553 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 44ms/step - accuracy: 0.6697 - loss: 0.6181Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 192ms/step - accuracy: 0.6696 - loss: 0.6180 - val_accuracy: 0.6778 - val_loss: 0.6122
# Epoch 67/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1089 occurrences
# Transition 1.0: 527 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 44ms/step - accuracy: 0.6837 - loss: 0.6048Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - accuracy: 0.6820 - loss: 0.6060 - val_accuracy: 0.6500 - val_loss: 0.6382
# Epoch 68/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1071 occurrences
# Transition 1.0: 545 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 45ms/step - accuracy: 0.6355 - loss: 0.6362Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - accuracy: 0.6400 - loss: 0.6334 - val_accuracy: 0.6389 - val_loss: 0.6375
# Epoch 69/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1086 occurrences
# Transition 1.0: 530 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 39ms/step - accuracy: 0.6673 - loss: 0.6144Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step - accuracy: 0.6670 - loss: 0.6151 - val_accuracy: 0.6667 - val_loss: 0.6156
# Epoch 70/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1081 occurrences
# Transition 1.0: 535 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 4s 42ms/step - accuracy: 0.6568 - loss: 0.6216Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.6565 - loss: 0.6219 - val_accuracy: 0.6222 - val_loss: 0.6468
# Epoch 71/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1110 occurrences
# Transition 1.0: 506 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 41ms/step - accuracy: 0.6645 - loss: 0.6181Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - accuracy: 0.6648 - loss: 0.6175 - val_accuracy: 0.7000 - val_loss: 0.5947
# Epoch 72/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1098 occurrences
# Transition 1.0: 518 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 6s 66ms/step - accuracy: 0.6666 - loss: 0.6145Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 338ms/step - accuracy: 0.6675 - loss: 0.6137 - val_accuracy: 0.6889 - val_loss: 0.5989
# Epoch 73/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1103 occurrences
# Transition 1.0: 513 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       2/Unknown 5s 122ms/step - accuracy: 0.6787 - loss: 0.6087Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 307ms/step - accuracy: 0.6797 - loss: 0.6076 - val_accuracy: 0.6778 - val_loss: 0.6044
# Epoch 74/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1083 occurrences
# Transition 1.0: 533 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 4s 49ms/step - accuracy: 0.6634 - loss: 0.6155Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - accuracy: 0.6666 - loss: 0.6136 - val_accuracy: 0.6889 - val_loss: 0.6006
# Epoch 75/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 525 occurrences
# Transition 0.0: 1091 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 46ms/step - accuracy: 0.6673 - loss: 0.6135Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.73762
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 217ms/step - accuracy: 0.6650 - loss: 0.6146 - val_accuracy: 0.7222 - val_loss: 0.5703
# Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.7000 - loss: 0.5855
# Accuracy after training: 0.699999988079071

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr e-3 + 4,2,1

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr e-6

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr e-4

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr e-5

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr e-3

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr e-1

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr e-4

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr e-7

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr e-5

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr e-3
