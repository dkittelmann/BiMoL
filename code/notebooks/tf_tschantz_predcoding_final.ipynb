# %% [markdown]
# imports

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2024-10-29 10:13:07.618171: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Helper and preprocessing functions

# %%
def tf_scale_imgs(imgs, scale_factor):
    return imgs * scale_factor + 0.5 * (1 - scale_factor) * tf.ones(imgs.shape)


def tf_scale_labels(labels, scale_factor):
    return labels * scale_factor + 0.5 * (1 - scale_factor) * tf.ones(labels.shape)


def tf_f_inv(x, act_fn):
    """ (activation_size, batch_size) """
    if act_fn == "LINEAR":
        m = x
    elif act_fn == "TANH":
        num = tf.ones_like(x) + x
        div = tf.ones_like(x) - x + 1e-7
        m = 0.5 * tf.math.log(num / div)
    elif act_fn == "LOGSIG":
        div = tf.ones_like(x) - x + 1e-7
        m = tf.math.log((x / div) + 1e-7)
    else:
        raise ValueError(f"{act_fn} not supported")
    return m


def img_preproc(x, y, dtype=tf.float32): 
  """Cast input image to a certain tf dtype and normalize them between 0 and 1."""
  x = tf.cast(x, dtype) / 255.
  #x = tf_scale_imgs(x, cf.img_scale)
  #y = tf_scale_labels(y, cf.label_scale)
  #x = tf_f_inv(x, "TANH")
  #y = tf.one_hot(y, depth=10)
  return x, y


def flatten(x, y): # adapt 
  #flattens a video image series (or batch of images) to (n_batch, n_steps, 1) d.
  shape = tf.shape(x)
  if len(shape) == 5: # hack, determining if it's a video or not (batch_size, n_steps, height, width, channels)
    x = tf.reshape(x, [shape[0], shape[1], -1])
  elif len(shape) == 4: # regular image (batch_size, height, width, channels)
    x = tf.reshape(x, [shape[0], -1])
  return x, y

def augment_images(batch_images, batch_labels):
    """
    Applies data augmentation on a batch of images without TensorFlow Addons.
    
    Parameters:
    batch_images: Tensor of shape (n_batch, 96, 96, 3)
    
    Returns:
    Augmented batch of images.
    """
    # Random horizontal flip
    augmented_images = tf.image.random_flip_left_right(batch_images)
    
    # Random brightness adjustment
    augmented_images = tf.image.random_brightness(augmented_images, max_delta=0.1)
    
    # Random contrast adjustment
    augmented_images = tf.image.random_contrast(augmented_images, lower=0.9, upper=1.1)
    
    # Random saturation adjustment
    augmented_images = tf.image.random_saturation(augmented_images, lower=0.9, upper=1.1)
    
    # Random hue adjustment
    augmented_images = tf.image.random_hue(augmented_images, max_delta=0.05)
    
    # Clipping to ensure pixel values are valid after transformations
    augmented_images = tf.clip_by_value(augmented_images, 0.0, 1.0)
    
    return augmented_images, batch_labels

# %%
resultspath = '/Users/denisekittelmann/Documents/Python/BiMoL/results/pcn/model_checkpoint_pcnoriginal_{epoch:02d}_{accuracy:.2f}.keras'

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath= resultspath,  
    monitor='accuracy',         # The metric to monitor for saving (e.g., 'val_loss', 'val_accuracy')
    save_best_only=True,        # Save only the best model 
    save_weights_only=False,    # False = Save the entire model; True = only save weights
    mode='max',                 # Set to 'min' for metrics like loss and 'max' for metrics like accuracy
    save_freq='epoch',          # Frequency of saving, e.g., epoch or batch 
    verbose=1                   # Print when saving a model
)

# %% [markdown]
# build the network

# %%
class CustomDense(tf.keras.layers.Dense):
    def call(self, inputs):
        """This works like a dense, except for the activation being called earlier."""
        # Apply the activation to the input first
        activated_input = self.activation(inputs)
        # Perform the matrix multiplication and add the bias
        output = tf.matmul(activated_input, self.kernel)
        if self.use_bias:
            output = output + self.bias
        return output


class PredictiveCodingNetwork(tf.keras.Sequential):
    def __init__(self, layers, vars, beta, **kwargs):
        """Initialize a PredictiveCodingNetwork"""
        super().__init__(layers, **kwargs)
        self.vars = tf.convert_to_tensor(vars, dtype=tf.float32)
        self.beta = beta

    def call_with_states(self, x):
        x_list = [x]
        for layer in self.layers:
            x = layer(x)
            x_list.append(x)
        return x_list

    def train_step(self, data):
        # Unpack the data. Its structure depends on your model and
        # on what you pass to `fit()`.
        x, y = data

        # do the stuff we do in train_epochs
        outputs, errors = self.infer(x, y)
        self.update_params(outputs, errors)

        # Update metrics (includes the metric that tracks the loss)
        pred = self.call(x)
        for metric in self.metrics:
            metric.update_state(y, pred)
        # Return a dict mapping metric names to current value
        return {m.name: m.result() for m in self.metrics}
    
   
    def infer(self, x_batch, y_batch=None, n_iter=50, return_sequence=False):
        """Note: while model call, call with states and model evaluate take
        2D input, train_step and infer take stacked 3D inputs."""
        if return_sequence:
            errors_time = []
            states_time = []
        errors = [None for _ in range(len(self.layers))]
        f_x_arr = [None for _ in range(len(self.layers))]
        f_x_deriv_arr = [None for _ in range(len(self.layers))]
        shape = x_batch.shape
        batch_size = shape[0]

        for itr in range(n_iter):
            # if its the first itr, set x to the current forward call
            if itr == 0:
                x = self.call_with_states(x_batch)

                if y_batch is not None:
                  x[-1] = y_batch
            else:
                # update g and x only for consecutive iterations
                for l in range(1, len(self.layers)):
                    g = tf.multiply(tf.matmul(errors[l], self.layers[l].kernel, transpose_b=True), f_x_deriv_arr[l])
                    x[l] = x[l] + self.beta * (-errors[l-1] + g)

            # update f_x etc for every iteration
            for l in range(len(self.layers)):
                f_x = self.layers[l].activation(x[l])
                f_x_deriv_fn = self.get_activation_derivative(self.layers[l].activation)
                f_x_deriv = f_x_deriv_fn(x[l])
                f_x_arr[l] = f_x
                f_x_deriv_arr[l] = f_x_deriv
                errors[l] = (x[l + 1] - tf.matmul(f_x, self.layers[l].kernel) - self.layers[l].bias) / self.vars[l]
            
            if return_sequence:
                errors_time.append(errors)
                states_time.append(x)

        # return what we want to return
        if return_sequence:
            states_time = [tf.stack(tensors, axis=1) for tensors in zip(*states_time)]
            errors_time = [tf.stack(tensors, axis=1) for tensors in zip(*errors_time)]
            return states_time, errors_time
        else:
            return x, errors
    
    # We need to check if we actually need call here.
    # Now, call will give us the result of the network after the first inference step
    # If we want to have the results after the last inference step, we would need to change this
    #def call(self, inputs, training=False):
    #    """Call, but time distributed."""
    #    x, errors = self.infer(inputs, return_sequence=False)
    #    return x[-1]

    def update_params(self, x, errors):
        """Update the model parameters."""
        batch_size = tf.cast(tf.shape(x[0])[0], tf.float32)
        gradients = []
        for l, layer in enumerate(self.layers):
            grad_w = self.vars[-1] * (1 / batch_size) * tf.matmul(tf.transpose(self.layers[l].activation(x[l])), errors[l])
            grad_b = self.vars[-1] * (1 / batch_size) * tf.reduce_sum(errors[l], axis=0)
            gradients.append((-grad_w, layer.kernel))
            gradients.append((-grad_b, layer.bias))
        self.optimizer.apply_gradients(gradients)

    def get_activation_derivative(self, activation):
        """Return a function for the derivative of the given activation function."""
        activation_fn = tf.keras.activations.get(activation)
        if activation_fn == tf.keras.activations.linear:
            return lambda x: tf.ones_like(x)
        elif activation_fn == tf.keras.activations.tanh:
            return lambda x: 1 - tf.square(tf.nn.tanh(x))
        elif activation_fn == tf.keras.activations.sigmoid:
            return lambda x: tf.nn.sigmoid(x) * (1 - tf.nn.sigmoid(x))
        else:
            raise ValueError(f"{activation} not supported")

# %% [markdown]
# Load the data

# %%
# Image paths 

img_dir_lead = '/Users/denisekittelmann/Documents/Python/BiMoL/data/Leading/'
img_dir_trail = '/Users/denisekittelmann/Documents/Python/BiMoL/data/Trailing/'
img_dir_test_lead = '/Users/denisekittelmann/Documents/Python/BiMoL/data/Test/Test_Leading/'
img_dir_test_trail = '/Users/denisekittelmann/Documents/Python/BiMoL/data/Test/Test_Trailing/'
class_names_L = ['barn', 'beach', 'cave', 'library', 'restaurant']
class_names_T = ['castle', 'Church', 'conference_room', 'forest'] # changed the order 
batch_size = None # adjust if needed, e.g., 32
image_size = (28,28)
validation_split = 0.1
seed = 123

# %%
# Image paths 

img_dir_lead = '/scratch/guetlid95/datasets/mcdermott_2024/Stimuli_2/Leading/'
img_dir_trail = '/scratch/guetlid95/datasets/mcdermott_2024/Stimuli_2/Trailing/' 
img_dir_test_lead = '/scratch/guetlid95/datasets/mcdermott_2024/Stimuli_2/Test/Test_Leading/' 
img_dir_test_trail = '/scratch/guetlid95/datasets/mcdermott_2024/Stimuli_2/Test/Test_Trailing/' 
class_names_L = ['barn', 'beach', 'cave', 'library', 'restaurant']
class_names_T = ['castle', 'Church', 'conference_room', 'forest'] # changed the order 
batch_size = 32
image_size = (28,28)
validation_split = 0.1
seed = 123

# %%
# Create a dict that assigns the correct labels for each leading-trailing imgage pair

"""
L1 = barn = label 0 
L2 = beach = label 1
L3 = library = label 3
L4 = restaurant = label 4 
L5 = cave = label 2

T6 = Church = label 1   
T7 = conference room = label 2
T8 = castle = label 0   
T9 = forest = label 3

MAPPING:

L1 -> T6 = 0.75 -> (0,1) 
L1 -> T7 = 0.25 -> (0,2)
L1 -> T8 = 0 -> (0,0)
L1 -> T9 = 0 -> (0,3)

L2 -> T6 = 0.75 -> (1,1) 
L2 -> T7 = 0.25 -> (1,2)
L2 -> T8 = 0 -> (1,0)
L2 -> T9 = 0 -> (1,3)

L3 -> T6 = 0 -> (3,1) 
L3 -> T7 = 0 -> (3,2)
L3 -> T8 = 0.5 -> (3,0)
L3 -> T9 = 0.5 -> (3,3)

L4 -> T6 = 0.25 -> (4,1) 
L4 -> T7 = 0.75 -> (4,2)
L4 -> T8 = 0 -> (4,0)
L4 -> T9 = 0 -> (4,3)

L5 -> T6 = 0.25 -> (2,1) 
L5 -> T7 = 0.75 -> (2,2)
L5 -> T8 = 0 -> (2,0)
L5 -> T9 = 0 -> (2,3)

"""


label_dict = {
    (0, 1): 0.0,
    (0, 2): 0.75,
    (0, 0): 0.25,
    (0, 3): 0.25,
    
    (1, 1): 0.0,
    (1, 2): 0.75,
    (1, 0): 0.25,
    (1, 3): 0.25,
    
    (3, 1): 0.75,
    (3, 2): 0.75,
    (3, 0): 0.50,
    (3, 3): 0.50,
    
    (4, 1): 0.75,
    (4, 2): 0.0,
    (4, 0): 0.25,
    (4, 3): 0.25,
    
    (2, 1): 0.75, 
    (2, 2): 0.0,
    (2, 0): 0.25,
    (2, 3): 0.25
}

# %%
# Generate image pairs 
def img_sequence(img_t1, img_t2, label_t1, label_t2, label_dict): 
    """This function stacks two images to construct an image pair and assigns a single label based on the label dictionary."""
    
    img_t1 = tf.cast(img_t1, dtype=tf.float32)
    img_t2 = tf.cast(img_t2, dtype=tf.float32)
    
    x = tf.concat([img_t1, img_t2], axis=0) 

    key_t1 = int(label_t1.numpy())
    key_t2 = int(label_t2.numpy())
 
    
    if (key_t1, key_t2) in label_dict:
        label = label_dict[(key_t1, key_t2)]
        #print(f"Label value found: {label}")
    else:
        print(f"Label pair {(key_t1, key_t2)} not found.")

    
    y = tf.cast(tf.random.uniform([]) < label, tf.float32)
    y = tf.expand_dims(y, axis=0)  
    
    return x,y

# %%
def generate_dataset(img_dirt1, img_dirt2, class_namest1, class_namest2, label_dict, image_size = None, seed = None, shuffle = False):       
    
    
    data_t1 = tf.keras.preprocessing.image_dataset_from_directory(
        img_dirt1, 
        label_mode = 'int',
        class_names= class_namest1,
        batch_size = None,
        color_mode = 'rgb',
        image_size = image_size, 
        #shuffle = True, 
        seed = seed
        )

    data_t2 = tf.keras.preprocessing.image_dataset_from_directory(
        img_dirt2, 
        label_mode = 'int',
        class_names= class_namest2,
        batch_size = None,
        color_mode = 'rgb', 
        image_size = image_size, 
        #shuffle = True, 
        seed = seed
    )
    
    if shuffle:
        data_t1.shuffle(99999, seed = seed*2)
        data_t2.shuffle(99999, seed = seed*3)
    
    # iterate through shuffled leading and trailing datasets
    leading = iter(data_t1)
    trailing = iter(data_t2) 
              
    while True:
        try:
            # Retrieve single samples
            img_t1, label_t1 = next(leading)
            img_t2, label_t2 = next(trailing)

            # Generate x, y pairs for single samples
            x, y = img_sequence(img_t1, img_t2, label_t1, label_t2, label_dict) 
            yield x, y
            
        except StopIteration:
            # Break the loop if no more samples
            break

# %%
# Build the validation dataset

seed = 123

val_dataset = tf.data.Dataset.from_generator(
    lambda: generate_dataset(img_dir_test_lead, img_dir_test_trail, class_names_L, class_names_T, label_dict, image_size = (28,28), seed = seed),
    output_signature=(
        tf.TensorSpec(shape=(56, 28, 3), dtype=tf.float32),  # shape of x 
        tf.TensorSpec(shape=(1), dtype=tf.float32)  # shape of y 
    )
) 

print(val_dataset)
# Out:
# <_FlatMapDataset element_spec=(TensorSpec(shape=(56, 28, 3), dtype=tf.float32, name=None), TensorSpec(shape=(1,), dtype=tf.float32, name=None))>

# %%
from collections import Counter

def check_transition_balance(dataset):
    transition_counts = Counter()
    
    # Use as_numpy_iterator to extract data from the dataset
    for image, label in dataset.as_numpy_iterator():
        
        transition_counts[label[0]] += 1  # Assuming label is a scalar or one-element array
    
    print("Transition frequencies:")
    for transition, count in transition_counts.items():
        print(f"Transition {transition}: {count} occurrences")

# %% [markdown]
# train the network

# %%
# define the model
model = PredictiveCodingNetwork([CustomDense(units=6, activation="sigmoid"),
                                 CustomDense(units=4, activation="sigmoid"), 
                                 CustomDense(units=1, activation="sigmoid")], 
                                vars=[1, 1, 1], # variances. This is super useless and in the code only the last variance is used
                                beta=0.1)

model.build([None, 4704]) 
model.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-7, weight_decay=1e-2), # wd only when overfitting occurs, lr  
              metrics= ["accuracy"],  
              loss="CategoricalCrossentropy",  # This is just a sham loss we need so model.evaluate doesn't throw an error. We don't use it.
              )

# save model before training
model.save('/Users/denisekittelmann/Documents/Python/BiMoL/results/pcn/final_model_pcn_lr1e-7_untrained.keras') 

# evaluate accuracy and train model
loss, accuracy = model.evaluate(val_dataset.batch(512).map(img_preproc).map(flatten)) 
print(f"Accuracy before training: {accuracy}")


n_epochs = 1000 

train_acc = []
val_acc = []
train_loss = []
val_loss = []

for i in range(n_epochs): 
    
    print(f"Epoch {i + 1}/{n_epochs}") 
    train_dataset = tf.data.Dataset.from_generator(
        lambda: generate_dataset(img_dir_lead, img_dir_trail, class_names_L, class_names_T, label_dict, image_size = (28,28), seed = i, shuffle = True),
        output_signature=(
            tf.TensorSpec(shape=(56, 28, 3), dtype=tf.float32),  # shape of x 
            tf.TensorSpec(shape=(1), dtype=tf.float32)  # shape of y 
        )
    ) 

    check_transition_balance(train_dataset)
    
    history = model.fit(train_dataset.shuffle(99999).batch(512).map(img_preproc).map(augment_images).map(flatten), 
            validation_data=val_dataset.batch(512).map(img_preproc).map(flatten),
            callbacks=[checkpoint_callback]) 
    
    
    train_acc.extend(history.history['accuracy'])
    val_acc.extend(history.history['val_accuracy'])
    train_loss.extend(history.history['loss'])
    val_loss.extend(history.history['val_loss'])


loss, accuracy = model.evaluate(val_dataset.batch(512).map(img_preproc).map(flatten)) 
print(f"Accuracy after training: {accuracy}")

model.save('/Users/denisekittelmann/Documents/Python/BiMoL/results/pcn/final_model_pcn_lr1e-7_trained.keras')
# Out:
# Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 687ms/step - accuracy: 0.6778 - loss: 3.8412e-08
# Accuracy before training: 0.6777777671813965
# Epoch 1/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1091 occurrences
# Transition 1.0: 525 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 10s 52ms/step - accuracy: 0.6768 - loss: 0.3241Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 222ms/step - accuracy: 0.6741 - loss: 0.3267 - val_accuracy: 0.7167 - val_loss: 3.3776e-08
# Epoch 2/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1063 occurrences
# Transition 1.0: 553 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 51ms/step - accuracy: 0.6872 - loss: 0.3131Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 214ms/step - accuracy: 0.6863 - loss: 0.3141 - val_accuracy: 0.7000 - val_loss: 3.5763e-08
# Epoch 3/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 539 occurrences
# Transition 0.0: 1077 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 78ms/step - accuracy: 0.6662 - loss: 0.3346Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 209ms/step - accuracy: 0.6638 - loss: 0.3370 - val_accuracy: 0.6667 - val_loss: 3.9736e-08
# Epoch 4/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 528 occurrences
# Transition 0.0: 1088 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 75ms/step - accuracy: 0.6749 - loss: 0.3257Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step - accuracy: 0.6720 - loss: 0.3287 - val_accuracy: 0.6778 - val_loss: 3.8412e-08
# Epoch 5/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1078 occurrences
# Transition 1.0: 538 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 44ms/step - accuracy: 0.6901 - loss: 0.3104Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - accuracy: 0.6873 - loss: 0.3132 - val_accuracy: 0.6667 - val_loss: 3.9736e-08
# Epoch 6/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1078 occurrences
# Transition 1.0: 538 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 45ms/step - accuracy: 0.6695 - loss: 0.3312Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - accuracy: 0.6641 - loss: 0.3366 - val_accuracy: 0.7111 - val_loss: 3.4438e-08
# Epoch 7/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1075 occurrences
# Transition 1.0: 541 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 72ms/step - accuracy: 0.6736 - loss: 0.3271Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 213ms/step - accuracy: 0.6720 - loss: 0.3288 - val_accuracy: 0.6556 - val_loss: 4.1061e-08
# Epoch 8/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 532 occurrences
# Transition 0.0: 1084 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 47ms/step - accuracy: 0.6701 - loss: 0.3306Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - accuracy: 0.6719 - loss: 0.3288 - val_accuracy: 0.7056 - val_loss: 3.5101e-08
# Epoch 9/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 539 occurrences
# Transition 0.0: 1077 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 78ms/step - accuracy: 0.6809 - loss: 0.3196Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.6818 - loss: 0.3188 - val_accuracy: 0.6333 - val_loss: 4.3710e-08
# Epoch 10/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1063 occurrences
# Transition 1.0: 553 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 45ms/step - accuracy: 0.6697 - loss: 0.3309Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - accuracy: 0.6679 - loss: 0.3327 - val_accuracy: 0.6889 - val_loss: 3.7087e-08
# Epoch 11/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 527 occurrences
# Transition 0.0: 1089 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 77ms/step - accuracy: 0.6844 - loss: 0.3162Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.6807 - loss: 0.3198 - val_accuracy: 0.6500 - val_loss: 4.1723e-08
# Epoch 12/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1093 occurrences
# Transition 1.0: 523 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 72ms/step - accuracy: 0.6654 - loss: 0.3355Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 212ms/step - accuracy: 0.6665 - loss: 0.3344 - val_accuracy: 0.6778 - val_loss: 3.8412e-08
# Epoch 13/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 536 occurrences
# Transition 0.0: 1080 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 44ms/step - accuracy: 0.6816 - loss: 0.3193Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 187ms/step - accuracy: 0.6800 - loss: 0.3209 - val_accuracy: 0.6611 - val_loss: 4.0399e-08
# Epoch 14/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1102 occurrences
# Transition 1.0: 514 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 74ms/step - accuracy: 0.6641 - loss: 0.3365Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - accuracy: 0.6623 - loss: 0.3383 - val_accuracy: 0.6611 - val_loss: 4.0399e-08
# Epoch 15/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1086 occurrences
# Transition 1.0: 530 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 70ms/step - accuracy: 0.6633 - loss: 0.3375Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step - accuracy: 0.6616 - loss: 0.3392 - val_accuracy: 0.6722 - val_loss: 3.9074e-08
# Epoch 16/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1074 occurrences
# Transition 1.0: 542 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       4/Unknown 3s 43ms/step - accuracy: 0.6732 - loss: 0.3274Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.6732 - loss: 0.3274 - val_accuracy: 0.7222 - val_loss: 3.3114e-08
# Epoch 17/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 537 occurrences
# Transition 0.0: 1079 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 67ms/step - accuracy: 0.6923 - loss: 0.3084Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - accuracy: 0.6889 - loss: 0.3117 - val_accuracy: 0.6778 - val_loss: 3.8412e-08
# Epoch 18/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1103 occurrences
# Transition 1.0: 513 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 74ms/step - accuracy: 0.6534 - loss: 0.3473Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 212ms/step - accuracy: 0.6577 - loss: 0.3430 - val_accuracy: 0.6667 - val_loss: 3.9736e-08
# Epoch 19/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1102 occurrences
# Transition 1.0: 514 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 75ms/step - accuracy: 0.6829 - loss: 0.3175Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 214ms/step - accuracy: 0.6803 - loss: 0.3202 - val_accuracy: 0.7278 - val_loss: 3.2451e-08
# Epoch 20/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1075 occurrences
# Transition 1.0: 541 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 74ms/step - accuracy: 0.6653 - loss: 0.3354Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 214ms/step - accuracy: 0.6667 - loss: 0.3340 - val_accuracy: 0.6667 - val_loss: 3.9736e-08
# Epoch 21/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 542 occurrences
# Transition 0.0: 1074 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 69ms/step - accuracy: 0.6693 - loss: 0.3316Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.6719 - loss: 0.3290 - val_accuracy: 0.6444 - val_loss: 4.2386e-08
# Epoch 22/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1067 occurrences
# Transition 1.0: 549 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 67ms/step - accuracy: 0.6711 - loss: 0.3296Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step - accuracy: 0.6727 - loss: 0.3280 - val_accuracy: 0.7111 - val_loss: 3.4438e-08
# Epoch 23/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1070 occurrences
# Transition 1.0: 546 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 90ms/step - accuracy: 0.6546 - loss: 0.3462Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 239ms/step - accuracy: 0.6596 - loss: 0.3411 - val_accuracy: 0.6778 - val_loss: 3.8412e-08
# Epoch 24/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 540 occurrences
# Transition 0.0: 1076 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 71ms/step - accuracy: 0.6849 - loss: 0.3158Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 220ms/step - accuracy: 0.6842 - loss: 0.3165 - val_accuracy: 0.7111 - val_loss: 3.4438e-08
# Epoch 25/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1076 occurrences
# Transition 1.0: 540 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 41ms/step - accuracy: 0.6734 - loss: 0.3271Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 183ms/step - accuracy: 0.6699 - loss: 0.3306 - val_accuracy: 0.6556 - val_loss: 4.1061e-08
# Epoch 26/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1075 occurrences
# Transition 1.0: 541 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 46ms/step - accuracy: 0.6762 - loss: 0.3246Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 191ms/step - accuracy: 0.6684 - loss: 0.3324 - val_accuracy: 0.6833 - val_loss: 3.7750e-08
# Epoch 27/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1083 occurrences
# Transition 1.0: 533 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 83ms/step - accuracy: 0.6562 - loss: 0.3442Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 215ms/step - accuracy: 0.6628 - loss: 0.3376 - val_accuracy: 0.6833 - val_loss: 3.7750e-08
# Epoch 28/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1081 occurrences
# Transition 1.0: 535 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 74ms/step - accuracy: 0.6800 - loss: 0.3207Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 215ms/step - accuracy: 0.6761 - loss: 0.3246 - val_accuracy: 0.6667 - val_loss: 3.9736e-08
# Epoch 29/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1070 occurrences
# Transition 1.0: 546 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 68ms/step - accuracy: 0.6765 - loss: 0.3242Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.6747 - loss: 0.3260 - val_accuracy: 0.6833 - val_loss: 3.7750e-08
# Epoch 30/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1079 occurrences
# Transition 1.0: 537 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 74ms/step - accuracy: 0.6761 - loss: 0.3244Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step - accuracy: 0.6713 - loss: 0.3293 - val_accuracy: 0.7000 - val_loss: 3.5763e-08
# Epoch 31/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1080 occurrences
# Transition 1.0: 536 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 74ms/step - accuracy: 0.6523 - loss: 0.3485Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - accuracy: 0.6605 - loss: 0.3404 - val_accuracy: 0.7222 - val_loss: 3.3114e-08
# Epoch 32/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1090 occurrences
# Transition 1.0: 526 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 74ms/step - accuracy: 0.6576 - loss: 0.3431Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 206ms/step - accuracy: 0.6601 - loss: 0.3405 - val_accuracy: 0.7222 - val_loss: 3.3114e-08
# Epoch 33/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 519 occurrences
# Transition 0.0: 1097 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 82ms/step - accuracy: 0.6686 - loss: 0.3322Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - accuracy: 0.6683 - loss: 0.3325 - val_accuracy: 0.6556 - val_loss: 4.1061e-08
# Epoch 34/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1084 occurrences
# Transition 1.0: 532 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 78ms/step - accuracy: 0.6591 - loss: 0.3416Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 214ms/step - accuracy: 0.6623 - loss: 0.3384 - val_accuracy: 0.6944 - val_loss: 3.6425e-08
# Epoch 35/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1058 occurrences
# Transition 1.0: 558 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 74ms/step - accuracy: 0.6905 - loss: 0.3101Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 214ms/step - accuracy: 0.6893 - loss: 0.3113 - val_accuracy: 0.6778 - val_loss: 3.8412e-08
# Epoch 36/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 542 occurrences
# Transition 0.0: 1074 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 70ms/step - accuracy: 0.6646 - loss: 0.3362Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.6656 - loss: 0.3352 - val_accuracy: 0.6944 - val_loss: 3.6425e-08
# Epoch 37/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 558 occurrences
# Transition 0.0: 1058 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 74ms/step - accuracy: 0.6773 - loss: 0.3235Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 209ms/step - accuracy: 0.6767 - loss: 0.3241 - val_accuracy: 0.6778 - val_loss: 3.8412e-08
# Epoch 38/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1075 occurrences
# Transition 1.0: 541 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 76ms/step - accuracy: 0.6603 - loss: 0.3403Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 227ms/step - accuracy: 0.6645 - loss: 0.3361 - val_accuracy: 0.6444 - val_loss: 4.2386e-08
# Epoch 39/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1057 occurrences
# Transition 1.0: 559 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 72ms/step - accuracy: 0.6630 - loss: 0.3377Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 213ms/step - accuracy: 0.6564 - loss: 0.3443 - val_accuracy: 0.7000 - val_loss: 3.5763e-08
# Epoch 40/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1087 occurrences
# Transition 1.0: 529 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 74ms/step - accuracy: 0.6655 - loss: 0.3351Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - accuracy: 0.6686 - loss: 0.3321 - val_accuracy: 0.7000 - val_loss: 3.5763e-08
# Epoch 41/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1064 occurrences
# Transition 1.0: 552 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 80ms/step - accuracy: 0.6694 - loss: 0.3311Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step - accuracy: 0.6657 - loss: 0.3348 - val_accuracy: 0.6667 - val_loss: 3.9736e-08
# Epoch 42/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 575 occurrences
# Transition 0.0: 1041 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 71ms/step - accuracy: 0.6717 - loss: 0.3289Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - accuracy: 0.6706 - loss: 0.3300 - val_accuracy: 0.7000 - val_loss: 3.5763e-08
# Epoch 43/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 520 occurrences
# Transition 0.0: 1096 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 82ms/step - accuracy: 0.6427 - loss: 0.3576Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 212ms/step - accuracy: 0.6487 - loss: 0.3516 - val_accuracy: 0.6833 - val_loss: 3.7750e-08
# Epoch 44/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1054 occurrences
# Transition 1.0: 562 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 71ms/step - accuracy: 0.6912 - loss: 0.3095Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.6905 - loss: 0.3102 - val_accuracy: 0.6667 - val_loss: 3.9736e-08
# Epoch 45/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1082 occurrences
# Transition 1.0: 534 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 75ms/step - accuracy: 0.6707 - loss: 0.3300Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 214ms/step - accuracy: 0.6705 - loss: 0.3302 - val_accuracy: 0.6833 - val_loss: 3.7750e-08
# Epoch 46/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 520 occurrences
# Transition 0.0: 1096 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 72ms/step - accuracy: 0.6726 - loss: 0.3278Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - accuracy: 0.6707 - loss: 0.3299 - val_accuracy: 0.7556 - val_loss: 2.9140e-08
# Epoch 47/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1091 occurrences
# Transition 1.0: 525 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 4s 38ms/step - accuracy: 0.6712 - loss: 0.3290Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 186ms/step - accuracy: 0.6676 - loss: 0.3327 - val_accuracy: 0.6500 - val_loss: 4.1723e-08
# Epoch 48/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1078 occurrences
# Transition 1.0: 538 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 42ms/step - accuracy: 0.6579 - loss: 0.3428Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - accuracy: 0.6603 - loss: 0.3403 - val_accuracy: 0.6778 - val_loss: 3.8412e-08
# Epoch 49/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1102 occurrences
# Transition 1.0: 514 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 68ms/step - accuracy: 0.6520 - loss: 0.3488Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 210ms/step - accuracy: 0.6533 - loss: 0.3475 - val_accuracy: 0.6611 - val_loss: 4.0399e-08
# Epoch 50/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1086 occurrences
# Transition 1.0: 530 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 75ms/step - accuracy: 0.6695 - loss: 0.3311Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 215ms/step - accuracy: 0.6725 - loss: 0.3281 - val_accuracy: 0.6944 - val_loss: 3.6425e-08
# Epoch 51/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1102 occurrences
# Transition 1.0: 514 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 75ms/step - accuracy: 0.6586 - loss: 0.3420Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 226ms/step - accuracy: 0.6598 - loss: 0.3409 - val_accuracy: 0.7111 - val_loss: 3.4438e-08
# Epoch 52/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1072 occurrences
# Transition 1.0: 544 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 77ms/step - accuracy: 0.6630 - loss: 0.3380Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.6656 - loss: 0.3353 - val_accuracy: 0.6556 - val_loss: 4.1061e-08
# Epoch 53/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1093 occurrences
# Transition 1.0: 523 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 77ms/step - accuracy: 0.6734 - loss: 0.3274Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.6743 - loss: 0.3264 - val_accuracy: 0.6389 - val_loss: 4.3048e-08
# Epoch 54/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1092 occurrences
# Transition 1.0: 524 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 76ms/step - accuracy: 0.6791 - loss: 0.3215Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 212ms/step - accuracy: 0.6770 - loss: 0.3236 - val_accuracy: 0.7000 - val_loss: 3.5763e-08
# Epoch 55/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1059 occurrences
# Transition 1.0: 557 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 70ms/step - accuracy: 0.6682 - loss: 0.3322Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 215ms/step - accuracy: 0.6692 - loss: 0.3312 - val_accuracy: 0.6500 - val_loss: 4.1723e-08
# Epoch 56/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 533 occurrences
# Transition 0.0: 1083 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 70ms/step - accuracy: 0.6656 - loss: 0.3351Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - accuracy: 0.6674 - loss: 0.3333 - val_accuracy: 0.6889 - val_loss: 3.7087e-08
# Epoch 57/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1096 occurrences
# Transition 1.0: 520 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 70ms/step - accuracy: 0.6667 - loss: 0.3341Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - accuracy: 0.6663 - loss: 0.3345 - val_accuracy: 0.6778 - val_loss: 3.8412e-08
# Epoch 58/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 523 occurrences
# Transition 0.0: 1093 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 62ms/step - accuracy: 0.6705 - loss: 0.3304Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 211ms/step - accuracy: 0.6743 - loss: 0.3265 - val_accuracy: 0.6111 - val_loss: 4.6359e-08
# Epoch 59/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 541 occurrences
# Transition 0.0: 1075 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 75ms/step - accuracy: 0.6663 - loss: 0.3343Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 215ms/step - accuracy: 0.6674 - loss: 0.3332 - val_accuracy: 0.6222 - val_loss: 4.5035e-08
# Epoch 60/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1063 occurrences
# Transition 1.0: 553 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 67ms/step - accuracy: 0.6760 - loss: 0.3246Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 209ms/step - accuracy: 0.6714 - loss: 0.3291 - val_accuracy: 0.6778 - val_loss: 3.8412e-08
# Epoch 61/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 542 occurrences
# Transition 0.0: 1074 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 70ms/step - accuracy: 0.6611 - loss: 0.3395Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step - accuracy: 0.6635 - loss: 0.3372 - val_accuracy: 0.6611 - val_loss: 4.0399e-08
# Epoch 62/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 535 occurrences
# Transition 0.0: 1081 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 67ms/step - accuracy: 0.6564 - loss: 0.3447Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 213ms/step - accuracy: 0.6582 - loss: 0.3428 - val_accuracy: 0.6389 - val_loss: 4.3048e-08
# Epoch 63/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1046 occurrences
# Transition 1.0: 570 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 67ms/step - accuracy: 0.6743 - loss: 0.3266Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 212ms/step - accuracy: 0.6744 - loss: 0.3264 - val_accuracy: 0.7278 - val_loss: 3.2451e-08
# Epoch 64/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1071 occurrences
# Transition 1.0: 545 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 62ms/step - accuracy: 0.6698 - loss: 0.3308Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step - accuracy: 0.6727 - loss: 0.3279 - val_accuracy: 0.7000 - val_loss: 3.5763e-08
# Epoch 65/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1077 occurrences
# Transition 1.0: 539 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 62ms/step - accuracy: 0.6804 - loss: 0.3202Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 197ms/step - accuracy: 0.6776 - loss: 0.3230 - val_accuracy: 0.6944 - val_loss: 3.6425e-08
# Epoch 66/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1059 occurrences
# Transition 1.0: 557 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 41ms/step - accuracy: 0.6655 - loss: 0.3353Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 180ms/step - accuracy: 0.6614 - loss: 0.3393 - val_accuracy: 0.6556 - val_loss: 4.1061e-08
# Epoch 67/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 564 occurrences
# Transition 0.0: 1052 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 87ms/step - accuracy: 0.6970 - loss: 0.3038Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 218ms/step - accuracy: 0.6915 - loss: 0.3093 - val_accuracy: 0.6833 - val_loss: 3.7750e-08
# Epoch 68/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1067 occurrences
# Transition 1.0: 549 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       4/Unknown 3s 37ms/step - accuracy: 0.6795 - loss: 0.3212Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 198ms/step - accuracy: 0.6795 - loss: 0.3212 - val_accuracy: 0.6778 - val_loss: 3.8412e-08
# Epoch 69/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1093 occurrences
# Transition 1.0: 523 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 71ms/step - accuracy: 0.6657 - loss: 0.3351Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 221ms/step - accuracy: 0.6665 - loss: 0.3343 - val_accuracy: 0.7000 - val_loss: 3.5763e-08
# Epoch 70/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1069 occurrences
# Transition 1.0: 547 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 73ms/step - accuracy: 0.6629 - loss: 0.3375Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 214ms/step - accuracy: 0.6678 - loss: 0.3327 - val_accuracy: 0.7000 - val_loss: 3.5763e-08
# Epoch 71/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1098 occurrences
# Transition 1.0: 518 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 72ms/step - accuracy: 0.6721 - loss: 0.3287Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - accuracy: 0.6708 - loss: 0.3299 - val_accuracy: 0.6500 - val_loss: 4.1723e-08
# Epoch 72/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1075 occurrences
# Transition 1.0: 541 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 71ms/step - accuracy: 0.6844 - loss: 0.3162Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 209ms/step - accuracy: 0.6821 - loss: 0.3184 - val_accuracy: 0.6722 - val_loss: 3.9074e-08
# Epoch 73/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1093 occurrences
# Transition 1.0: 523 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 73ms/step - accuracy: 0.6656 - loss: 0.3352Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 212ms/step - accuracy: 0.6694 - loss: 0.3313 - val_accuracy: 0.6222 - val_loss: 4.5035e-08
# Epoch 74/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 0.0: 1056 occurrences
# Transition 1.0: 560 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 72ms/step - accuracy: 0.6757 - loss: 0.3248Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 203ms/step - accuracy: 0.6764 - loss: 0.3241 - val_accuracy: 0.6500 - val_loss: 4.1723e-08
# Epoch 75/75
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# Transition frequencies:
# Transition 1.0: 549 occurrences
# Transition 0.0: 1067 occurrences
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 3s 44ms/step - accuracy: 0.6642 - loss: 0.3363Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.70421
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - accuracy: 0.6582 - loss: 0.3423 - val_accuracy: 0.6833 - val_loss: 3.7750e-08
# Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.6944 - loss: 3.6425e-08
# Accuracy after training: 0.6944444179534912

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr = 1e-7

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr = 1e-3

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr = 1e-5

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr = 1e-5

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr = 1e-4

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr = 1e-3

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr = 1e-7

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr = 1e-5

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr = 1e-5

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr 1e-7

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# lr = 1-e3

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
for x, y in train_dataset.shuffle(99999).batch(32).map(img_preproc).take(1):
    print("x shape:",x.shape)
    print("label y:", y.shape)
    plt.imshow(x[0])
