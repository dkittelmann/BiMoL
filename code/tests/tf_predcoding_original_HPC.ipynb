# %% [markdown]
# imports

# %%
import tensorflow as tf
#import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2024-10-18 10:56:41.693815: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Helper and preprocessing functions

# %%
def tf_scale_imgs(imgs, scale_factor):
    return imgs * scale_factor + 0.5 * (1 - scale_factor) * tf.ones(imgs.shape)


def tf_scale_labels(labels, scale_factor):
    return labels * scale_factor + 0.5 * (1 - scale_factor) * tf.ones(labels.shape)


def tf_f_inv(x, act_fn):
    """ (activation_size, batch_size) """
    if act_fn == "LINEAR":
        m = x
    elif act_fn == "TANH":
        num = tf.ones_like(x) + x
        div = tf.ones_like(x) - x + 1e-7
        m = 0.5 * tf.math.log(num / div)
    elif act_fn == "LOGSIG":
        div = tf.ones_like(x) - x + 1e-7
        m = tf.math.log((x / div) + 1e-7)
    else:
        raise ValueError(f"{act_fn} not supported")
    return m


def img_preproc(x, y, dtype=tf.float32): # add: tf.image.resize(image, [28,28])
  """Cast input image to a certain tf dtype and normalize them between 0 and 1."""
  x = tf.cast(x, dtype) / 255.
  #x = tf_scale_imgs(x, cf.img_scale)
  #y = tf_scale_labels(y, cf.label_scale)
  #x = tf_f_inv(x, "TANH")
  #y = tf.one_hot(y, depth=10)
  return x, y


def flatten(x, y): # adapt 
  #flattens a video image series (or batch of images) to (n_batch, n_steps, 1) d.
  shape = tf.shape(x)
  if len(shape) == 5: # hack, determining if it's a video or not (batch_size, n_steps, height, width, channels)
    x = tf.reshape(x, [shape[0], shape[1], -1])
  elif len(shape) == 4: # regular image (batch_size, height, width, channels)
    x = tf.reshape(x, [shape[0], -1])
  return x, y

# %%
resultspath = '/Users/denisekittelmann/Documents/Python/BiMoL/results/pcn/model_checkpoint_{epoch:02d}_{accuracy:.2f}.keras'

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath= resultspath,  
    monitor='accuracy',         # The metric to monitor for saving (e.g., 'val_loss', 'val_accuracy')
    save_best_only=True,        # Save only the best model 
    save_weights_only=False,    # False = Save the entire model; True = only save weights
    mode='max',                 # Set to 'min' for metrics like loss and 'max' for metrics like accuracy
    save_freq='epoch',          # Frequency of saving, e.g., epoch or batch 
    verbose=1                   # Print when saving a model
)

# %% [markdown]
# build the network

# %%
class CustomDense(tf.keras.layers.Dense):
    def call(self, inputs):
        """This works like a dense, except for the activation being called earlier."""
        # Apply the activation to the input first
        activated_input = self.activation(inputs)
        # Perform the matrix multiplication and add the bias
        output = tf.matmul(activated_input, self.kernel)
        if self.use_bias:
            output = output + self.bias
        return output


class PredictiveCodingNetwork(tf.keras.Sequential):
    def __init__(self, layers, vars, beta, **kwargs):
        """Initialize a PredictiveCodingNetwork"""
        super().__init__(layers, **kwargs)
        self.vars = tf.convert_to_tensor(vars, dtype=tf.float32)
        self.beta = beta

    def call_with_states(self, x):
        """Note: while model call, call with states and model evaluate take
        2D input, train_step and infer take stacked 3D inputs."""
        x_list = [x]
        for layer in self.layers:
            x = layer(x)
            x_list.append(x)
        return x_list

    def train_step(self, data):
        """Note: while model call, call with states and model evaluate take
        2D input, train_step and infer take stacked 3D inputs."""
        # Unpack the data. Its structure depends on your model and
        # on what you pass to `fit()`.
        x, y = data

        # do the stuff we do in train_epochs
        outputs, errors = self.infer(x, y)
        self.update_params(outputs, errors)

        # Update metrics (includes the metric that tracks the loss)
        pred = self.call(x)
        for metric in self.metrics:
            metric.update_state(y[:, -1], pred[:, -1])
        # Return a dict mapping metric names to current value
        return {m.name: m.result() for m in self.metrics}
    
   
    def infer(self, x_batch, y_batch=None, return_sequence=False):
        """Note: while model call, call with states and model evaluate take
        2D input, train_step and infer take stacked 3D inputs."""
        if return_sequence:
            errors_time = []
            states_time = []
        errors = [None for _ in range(len(self.layers))]
        f_x_arr = [None for _ in range(len(self.layers))]
        f_x_deriv_arr = [None for _ in range(len(self.layers))]
        shape = x_batch.shape
        batch_size, n_steps = shape[0], shape[1]

        for itr in range(n_steps):
            #print("BATCH SHAPE: ", x_batch.shape)
            # always update the current forward call
            x_forward_cur = self.call_with_states(x_batch[:, itr])
            if y_batch is not None:
                x_forward_cur[-1] = y_batch[:, itr]
            # if its the first itr, set x to the current forward call
            if itr == 0:
                x = x_forward_cur
            if itr != 0:
                # update g and x only for consecutive iterations
                for l in range(1, len(self.layers)):
                    g = tf.multiply(tf.matmul(errors[l], self.layers[l].kernel, transpose_b=True), f_x_deriv_arr[l])
                    x[l] = x[l] + (x_forward_cur[l] - x_forward_prev[l]) + self.beta * (-errors[l-1] + g)
            # update f_x etc for every iteration
            for l in range(len(self.layers)):
                f_x = self.layers[l].activation(x[l])
                f_x_deriv_fn = self.get_activation_derivative(self.layers[l].activation)
                f_x_deriv = f_x_deriv_fn(x[l])
                f_x_arr[l] = f_x
                f_x_deriv_arr[l] = f_x_deriv
                errors[l] = (x[l + 1] - tf.matmul(f_x, self.layers[l].kernel) - self.layers[l].bias) / self.vars[l]
            # fill the old forward pass with the current forward pass
            x_forward_prev = x_forward_cur
            
            if return_sequence:
                errors_time.append(errors)
                states_time.append(x)
        if return_sequence:
            states_time = [tf.stack(tensors, axis=1) for tensors in zip(*states_time)]
            errors_time = [tf.stack(tensors, axis=1) for tensors in zip(*errors_time)]
            return states_time, errors_time
        else:
            return x, errors
    
    
    def call(self, inputs, training=False):
        """Call, but time distributed."""
        x, errors = self.infer(inputs, return_sequence=True)
        return x[-1]

    def update_params(self, x, errors):
        """Update the model parameters."""
        batch_size = tf.cast(tf.shape(x[0])[0], tf.float32)
        gradients = []
        for l, layer in enumerate(self.layers):
            grad_w = self.vars[-1] * (1 / batch_size) * tf.matmul(tf.transpose(self.layers[l].activation(x[l])), errors[l])
            grad_b = self.vars[-1] * (1 / batch_size) * tf.reduce_sum(errors[l], axis=0)
            gradients.append((-grad_w, layer.kernel))
            gradients.append((-grad_b, layer.bias))
        self.optimizer.apply_gradients(gradients)

    def get_activation_derivative(self, activation):
        """Return a function for the derivative of the given activation function."""
        activation_fn = tf.keras.activations.get(activation)
        if activation_fn == tf.keras.activations.linear:
            return lambda x: tf.ones_like(x)
        elif activation_fn == tf.keras.activations.tanh:
            return lambda x: 1 - tf.square(tf.nn.tanh(x))
        elif activation_fn == tf.keras.activations.sigmoid:
            return lambda x: tf.nn.sigmoid(x) * (1 - tf.nn.sigmoid(x))
        else:
            raise ValueError(f"{activation} not supported")

# %% [markdown]
# Load the data

# %%
# Image paths 

img_dir_lead = '/Users/denisekittelmann/Documents/Python/BiMoL/data/Leading/'
img_dir_trail = '/Users/denisekittelmann/Documents/Python/BiMoL/data/Trailing/'
img_dir_test_lead = '/Users/denisekittelmann/Documents/Python/BiMoL/data/Test/Test_Leading/'
img_dir_test_trail = '/Users/denisekittelmann/Documents/Python/BiMoL/data/Test/Test_Trailing/'
class_names_L = ['barn', 'beach', 'cave', 'library', 'restaurant']
class_names_T = ['castle', 'Church', 'conference_room', 'forest'] # changed the order 
batch_size = None # adjust if needed, e.g., 32
image_size = (28,28)
validation_split = 0.1
seed = 123

# %%
# Image paths 

img_dir_lead = '/scratch/guetlid95/datasets/mcdermott_2024/Stimuli_2/Leading/'
img_dir_trail = '/scratch/guetlid95/datasets/mcdermott_2024/Stimuli_2/Trailing/' 
img_dir_test_lead = '/scratch/guetlid95/datasets/mcdermott_2024/Stimuli_2/Test/Test_Leading/' 
img_dir_test_trail = '/scratch/guetlid95/datasets/mcdermott_2024/Stimuli_2/Test/Test_Trailing/' 
class_names_L = ['barn', 'beach', 'cave', 'library', 'restaurant']
class_names_T = ['castle', 'Church', 'conference_room', 'forest'] # changed the order 
batch_size = 32
image_size = (28,28)
validation_split = 0.1
seed = 123

# %%
# Create a dict that assigns the correct labels for each leading-trailing img pair

"""
L1 = barn = label 0 
L2 = beach = label 1
L3 = library = label 3
L4 = restaurant = label 4 
L5 = cave = label 2

T6 = Church = label 1   
T7 = conference room = label 2
T8 = castle = label 0   
T9 = forest = label 3

MAPPING:

L1 -> T6 = 0.75 -> (0,1) 
L1 -> T7 = 0.25 -> (0,2)
L1 -> T8 = 0 -> (0,0)
L1 -> T9 = 0 -> (0,3)

L2 -> T6 = 0.75 -> (1,1) 
L2 -> T7 = 0.25 -> (1,2)
L2 -> T8 = 0 -> (1,0)
L2 -> T9 = 0 -> (1,3)

L3 -> T6 = 0 -> (3,1) 
L3 -> T7 = 0 -> (3,2)
L3 -> T8 = 0.5 -> (3,0)
L3 -> T9 = 0.5 -> (3,3)

L4 -> T6 = 0.25 -> (4,1) 
L4 -> T7 = 0.75 -> (4,2)
L4 -> T8 = 0 -> (4,0)
L4 -> T9 = 0 -> (4,3)

L5 -> T6 = 0.25 -> (2,1) 
L5 -> T7 = 0.75 -> (2,2)
L5 -> T8 = 0 -> (2,0)
L5 -> T9 = 0 -> (2,3)

"""



label_dict = {
    (0, 1): 1.,
    (0, 2): 1.,
    (0, 0): 1.,
    (0, 3): 1.,
    (1, 1): 0.0,
    (1, 2): 0.0,
    (1, 0): 0.,
    (1, 3): 0.,
    (3, 1): 0.0,
    (3, 2): 0.0,
    (3, 0): 0.,
    (3, 3): 0.,
    (4, 1): 0.0,
    (4, 2): 0.0,
    (4, 0): 0.,
    (4, 3): 0.,
    (2, 1): 0.0,
    (2, 2): 0.0,
    (2, 0): 0.,
    (2, 3): 0.
}

label_dict = {
    (0, 1): 0.0,
    (0, 2): 0.0,
    (0, 0): 0.25,
    (0, 3): 0.75,
    (1, 1): 0.0,
    (1, 2): 0.0,
    (1, 0): 0.25,
    (1, 3): 0.75,
    (3, 1): 0.0,
    (3, 2): 0.0,
    (3, 0): 0.25,
    (3, 3): 0.75,
    (4, 1): 0.0,
    (4, 2): 0.0,
    (4, 0): 0.25,
    (4, 3): 0.75,
    (2, 1): 0.0,
    (2, 2): 0.0,
    (2, 0): 0.5,
    (2, 3): 0.5
}




def imgsequence(img_t1, img_t2, label_t1, label_t2, label_dict):  # adapt: 50 due to error iterations, experimental 
    """This function stacks images and prepares labels accordingly."""
    
    
    img_t1 = tf.cast(img_t1, dtype=tf.float32)
    img_t2 = tf.cast(img_t2, dtype=tf.float32)
    
    # stack imgs from both datatsets into a sequence of 4 img
    x = tf.stack([img_t1, img_t1, img_t2, img_t2], axis = 0)
    #print("Shape of x after stacking:", x.shape)

    
    key_t1 = int(label_t1.numpy())
    key_t2 = int(label_t2.numpy())
   # print("Current label pair:", (key_t1, key_t2))
   
    # Check if the key exists
    if (key_t1, key_t2) in label_dict:
       label_value = label_dict[(key_t1, key_t2)]
        #print(f"Label value found: {label_value}")
    else:
        print(f"Label pair {(key_t1, key_t2)} not found, defaulting to 0")
        label_value = 0  
    
    # Generate the label sequence 
    y_sequence = [[label_value], [label_value], [label_value], [label_value]]
    y = tf.convert_to_tensor(y_sequence, dtype=tf.float32)  # Shape (4, 1)

    #print("Generated labels (y):", y.numpy())
    #print("Shape of y:", y.shape)

    return x, y

# %%
# alternative img sequence function 
def img_sequence2(img_t1, img_t2, label_t1, label_t2, label_dict): 
    """This function prepares an image pair and assigns a single label based on the label dictionary."""
    
    
    img_t1 = tf.cast(img_t1, dtype=tf.float32)
    img_t2 = tf.cast(img_t2, dtype=tf.float32)
    
    
    x = tf.stack([img_t1, img_t2], axis=1) 
    print("Shape of x after stacking:", x.shape)

    
    key_t1 = int(label_t1.numpy())
    key_t2 = int(label_t2.numpy())
    print("Current label pair:", (key_t1, key_t2)) 
    
    if (key_t1, key_t2) in label_dict:
        label = label_dict[(key_t1, key_t2)]
        print(f"Label value found: {label}")
    else:
        print(f"Label pair {(key_t1, key_t2)} not found.")

    
    y = tf.convert_to_tensor(label, dtype=tf.float32)  

    print("Generated label (y):", y.numpy())
    print("Shape of y:", y.shape)

    return x, y

# %%
def generate_dataset(img_dirt1, img_dirt2, class_namest1, class_namest2, label_dict, image_size = None, seed = None):       
    
    tf.random.set_seed(seed)
    
    data_t1 = tf.keras.preprocessing.image_dataset_from_directory(
        img_dirt1, 
        label_mode = 'int',
        class_names= class_namest1,
        batch_size = None,
        color_mode = 'rgb',
        image_size = image_size, 
        #shuffle = True, 
        seed = seed
        )

    data_t2 = tf.keras.preprocessing.image_dataset_from_directory(
        img_dirt2, 
        label_mode = 'int',
        class_names= class_namest2,
        batch_size = None,
        color_mode = 'rgb', 
        image_size = image_size, 
        #shuffle = True, 
        seed = seed
    )
    
    data_t1.shuffle(99999)
    data_t2.shuffle(99999)
    
    # iterate through shuffled leading and trailing datasets
    leading = iter(data_t1)
    trailing = iter(data_t2) 
              
    while True:
        try:
            # Retrieve single samples
            img_t1, label_t1 = next(leading)
            img_t2, label_t2 = next(trailing)
            print("test img shapes.", img_t1.shape, img_t2.shape)
            print("Shape of label_t1:", label_t1.shape)
            print("Shape of label_t2:", label_t2.shape)

            # Generate x, y pairs for single samples
            x, y = img_sequence2(img_t1, img_t2, label_t1, label_t2, label_dict) # batch_size, imgimg, 28, 28, 3
            print("test x:", x.shape)
            print("test y:", y.shape) 
            yield x, y
            
        except StopIteration:
            # Break the loop if no more samples
            break
        
        
# Create new dataset 
#n_steps = 4
#seed = 123
#batch_size = 32
#dataset = tf.data.Dataset.from_generator(
 #   lambda: generate_dataset(img_dir_lead, img_dir_trail, class_names_L, class_names_T, label_dict, image_size = (28,28), seed = seed),
  #  output_signature=(
   #     tf.TensorSpec(shape=(n_steps, 28, 28, 3), dtype=tf.float32),  # shape of x 2352; skip batch_size -> dataset.batch()
    #    tf.TensorSpec(shape=(n_steps, 1), dtype=tf.float32)  # shape of y 
    #)
#) 

#print(dataset)

#for x, y in dataset.batch(32).take(1):
#    print("test x:", x.shape)  # Should print (32, 4, 28, 28, 3)
#    print("test y:", y.shape)

# %%
# Build val_dataset 
#n_steps = 4 # adapt to 50 
seed = 123
#batch_size = 32
val_dataset = tf.data.Dataset.from_generator(
    lambda: generate_dataset(img_dir_test_lead, img_dir_test_trail, class_names_L, class_names_T, label_dict, image_size = (28,28), seed = seed),
    output_signature=(
        tf.TensorSpec(shape=(56, 28, 3), dtype=tf.float32),  # shape of x 2352; skip batch_size -> dataset.batch()
        tf.TensorSpec(shape=(1), dtype=tf.float32)  # shape of y 
    )
) 

print(val_dataset)
# Out:
# <_FlatMapDataset element_spec=(TensorSpec(shape=(56, 28, 3), dtype=tf.float32, name=None), TensorSpec(shape=(1,), dtype=tf.float32, name=None))>

# %%
def frame_accuracy(i):
    def accuracy_per_frame(y_true, y_pred):
        acc = tf.keras.metrics.Accuracy()
        acc.update_state(y_true[:, i, 0], tf.round(y_pred[:, i, 0]))
        return acc.result()
    return accuracy_per_frame

# %%
class AccuracyPerSequence(tf.keras.callbacks.Callback):
        
    def on_epoch_end(self, epoch, logs=None):
        all_targets = []
        all_predictions = []

        # Get predictions and true labels for each batch
        for batch in self.validation_dataset:
            inputs, targets = batch
            predictions = self.model.predict_on_batch(inputs)

            # Calculate accuracy per sequence for each frame and store them
            sequence_accuracies = []
            for j in range(predictions.shape[0]):  # iterate over each sequence in the batch
                accuracies = []
                for i in range(4):  
                    accuracy_metric = tf.keras.metrics.Accuracy()
                    accuracy_metric.update_state(targets[j, i], predictions[j, i])
                    accuracies.append(accuracy_metric.result().numpy())
                sequence_accuracies.append(accuracies)

            print(f"Epoch {epoch + 1} - Sequence-wise Accuracies: {sequence_accuracies}")

# %% [markdown]
# train the network

# %%
def debug_preproc(x, y):
    x_shape = tf.shape(x)
    #x = tf.reshape(x[:, 1:3], [x_shape[0], 1, x_shape[-1] * 2])
    x = tf.concat([x[:, 0], x[:, -1]], axis=1)[:, None, :]
    print(x.shape)
    y = y[:, 0]
    return x, y

# %%
# define the model
model = PredictiveCodingNetwork([CustomDense(units=32, activation="tanh"),
                                 CustomDense(units=16, activation="tanh"),
                                 CustomDense(units=1, activation="sigmoid")],
                                vars=[1, 1, 1], # variances. This is super useless and in the code only the last variance is used
                                beta=0.1)

model.build([None, 2352]) 
model.compile(optimizer=tf.keras.optimizers.AdamW(1e-3),
              metrics= ["accuracy"],  # , [SequenceAccuracy], [frame_accuracy(i) for i in range(4)]
              loss="CategoricalCrossentropy",  # This is just a sham loss we need so model.evaluate doesn't throw an error. We don't use it.
              )

# evaluate accuracy and train model
loss, accuracy = model.evaluate(val_dataset.batch(512).map(img_preproc).map(flatten)) 
print(f"Accuracy before training: {accuracy}")

#print("Weights before training:")
#for i, layer_weights in enumerate(model.get_weights()):
#    print(f"Layer {i} weights:\n{layer_weights}\n")


for i in range(1): 
    
    train_dataset = tf.data.Dataset.from_generator(
        lambda: generate_dataset(img_dir_lead, img_dir_trail, class_names_L, class_names_T, label_dict, image_size = (28,28), seed = seed),
        output_signature=(
            tf.TensorSpec(shape=(n_steps, 28, 28, 3), dtype=tf.float32),  # shape of x 
            tf.TensorSpec(shape=(n_steps, 1), dtype=tf.float32)  # shape of y 
        )
    ) 
    #for x, y in train_dataset.batch(32).map(img_preproc).map(flatten).take(1):
    #    pass
    #out = model(x)
    #print("EEEVAKUTAUIBNSANFIJASDIBG", model.evaluate(x, y))
    #print(out)
    #raise ValueError("STOP HERE")

    history = model.fit(train_dataset.shuffle(99999).batch(512).map(img_preproc).map(flatten), #  reshuffle_each_iteration=True
            validation_data=val_dataset.batch(512).map(img_preproc).map(flatten),
            callbacks=[checkpoint_callback], epochs=25)

#print("\nWeights after training:")
#for i, layer_weights in enumerate(model.get_weights()):
#    print(f"Layer {i} weights:\n{layer_weights}\n")

loss, accuracy = model.evaluate(val_dataset.batch(512).map(img_preproc).map(flatten)) 
print(f"Accuracy after training: {accuracy}")
# Out:
# Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.0000e+00 - loss: 2.9802e-08
# Accuracy before training: 0.0
# Epoch 1/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       2/Unknown 7s 565ms/step - accuracy: 0.0000e+00 - loss: 0.1603Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 8s 504ms/step - accuracy: 0.0000e+00 - loss: 0.1593 - val_accuracy: 0.0000e+00 - val_loss: 2.9802e-08
# Epoch 2/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step - accuracy: 0.0000e+00 - loss: 0.1667Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 2: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 489ms/step - accuracy: 0.0000e+00 - loss: 0.1634 - val_accuracy: 0.0000e+00 - val_loss: 2.9802e-08
# Epoch 3/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step - accuracy: 4.8828e-04 - loss: 0.1597Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 3: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 503ms/step - accuracy: 0.0191 - loss: 0.1589 - val_accuracy: 0.1778 - val_loss: 2.9802e-08
# Epoch 4/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step - accuracy: 0.1743 - loss: 0.1498Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 4: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 487ms/step - accuracy: 0.1650 - loss: 0.1545 - val_accuracy: 0.0333 - val_loss: 2.9802e-08
# Epoch 5/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step - accuracy: 0.0757 - loss: 0.1729Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 5: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 492ms/step - accuracy: 0.0650 - loss: 0.1665 - val_accuracy: 0.0000e+00 - val_loss: 2.9802e-08
# Epoch 6/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step - accuracy: 0.0000e+00 - loss: 0.1434Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 6: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 513ms/step - accuracy: 0.0000e+00 - loss: 0.1564 - val_accuracy: 0.0000e+00 - val_loss: 2.9802e-08
# Epoch 7/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step - accuracy: 0.0000e+00 - loss: 0.1674Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 7: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 510ms/step - accuracy: 0.0000e+00 - loss: 0.1651 - val_accuracy: 0.0000e+00 - val_loss: 2.9802e-08
# Epoch 8/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step - accuracy: 0.0000e+00 - loss: 0.1655Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 8: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 489ms/step - accuracy: 0.0000e+00 - loss: 0.1637 - val_accuracy: 0.0000e+00 - val_loss: 2.9802e-08
# Epoch 9/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step - accuracy: 0.0000e+00 - loss: 0.1782Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 9: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 487ms/step - accuracy: 0.0000e+00 - loss: 0.1690 - val_accuracy: 0.0000e+00 - val_loss: 2.9802e-08
# Epoch 10/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step - accuracy: 0.0000e+00 - loss: 0.1528Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 10: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 491ms/step - accuracy: 0.0000e+00 - loss: 0.1583 - val_accuracy: 0.0000e+00 - val_loss: 2.9802e-08
# Epoch 11/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step - accuracy: 0.0000e+00 - loss: 0.1641Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 11: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 487ms/step - accuracy: 0.0000e+00 - loss: 0.1637 - val_accuracy: 0.0000e+00 - val_loss: 2.9802e-08
# Epoch 12/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step - accuracy: 0.0000e+00 - loss: 0.1700Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 12: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 498ms/step - accuracy: 0.0000e+00 - loss: 0.1659 - val_accuracy: 0.0000e+00 - val_loss: 2.9802e-08
# Epoch 13/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step - accuracy: 0.0000e+00 - loss: 0.1647Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 13: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 441ms/step - accuracy: 0.0000e+00 - loss: 0.1638 - val_accuracy: 0.0000e+00 - val_loss: 2.9802e-08
# Epoch 14/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step - accuracy: 0.0020 - loss: 0.1582  Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 14: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 468ms/step - accuracy: 0.0040 - loss: 0.1598 - val_accuracy: 0.0333 - val_loss: 2.9802e-08
# Epoch 15/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - accuracy: 0.2373 - loss: 0.1713Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 15: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - accuracy: 0.3289 - loss: 0.1650 - val_accuracy: 0.4833 - val_loss: 2.9802e-08
# Epoch 16/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step - accuracy: 0.6650 - loss: 0.1564Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 16: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 490ms/step - accuracy: 0.6692 - loss: 0.1589 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 17/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step - accuracy: 0.6787 - loss: 0.1721Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 17: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - accuracy: 0.6781 - loss: 0.1688 - val_accuracy: 0.4833 - val_loss: 2.9802e-08
# Epoch 18/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step - accuracy: 0.6597 - loss: 0.1694Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 18: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 483ms/step - accuracy: 0.6673 - loss: 0.1683 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 19/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step - accuracy: 0.6763 - loss: 0.1600Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 19: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 458ms/step - accuracy: 0.6789 - loss: 0.1606 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 20/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step - accuracy: 0.6953 - loss: 0.1503Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 20: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 446ms/step - accuracy: 0.6879 - loss: 0.1537 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 21/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.6665 - loss: 0.1698Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 21: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 431ms/step - accuracy: 0.6760 - loss: 0.1640 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 22/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step - accuracy: 0.6753 - loss: 0.1585Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 22: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 451ms/step - accuracy: 0.6792 - loss: 0.1601 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 23/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step - accuracy: 0.6992 - loss: 0.1546Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 23: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 444ms/step - accuracy: 0.6893 - loss: 0.1592 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 24/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step - accuracy: 0.6768 - loss: 0.1686Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 24: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 660ms/step - accuracy: 0.6802 - loss: 0.1652 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 25/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# 2/4 ━━━━━━━━━━━━━━━━━━━━ 1s 585ms/step - accuracy: 0.7031 - loss: 0.1577Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 25: accuracy did not improve from 0.90718
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 489ms/step - accuracy: 0.6914 - loss: 0.1628 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 694ms/step - accuracy: 0.5000 - loss: 2.9802e-08
# Accuracy after training: 0.5

# %%
plt.plot(history.history["loss"], label="Training Loss") # val loss 
plt.plot(history.history["accuracy"], label="Training Accuracy")


plt.plot(history.history["val_loss"], label="Validation Loss") # val loss 
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")

plt.legend()
plt.xlabel("Epochs")
plt.show()

# %%
# define the model
model = PredictiveCodingNetwork([CustomDense(units=32, activation="tanh"),
                                 CustomDense(units=16, activation="tanh"),
                                 CustomDense(units=1, activation="sigmoid")],
                                vars=[1, 1, 1], # variances. This is super useless and in the code only the last variance is used
                                beta=0.1)

model.build([None, 2352]) 
model.compile(optimizer=tf.keras.optimizers.AdamW(1e-1),
              metrics= ["accuracy"],  # , [SequenceAccuracy], [frame_accuracy(i) for i in range(4)]
              loss="CategoricalCrossentropy",  # This is just a sham loss we need so model.evaluate doesn't throw an error. We don't use it.
              )

# evaluate accuracy and train model
loss, accuracy = model.evaluate(val_dataset.batch(512).map(img_preproc).map(flatten)) 
print(f"Accuracy before training: {accuracy}")

#print("Weights before training:")
#for i, layer_weights in enumerate(model.get_weights()):
#    print(f"Layer {i} weights:\n{layer_weights}\n")

n_epochs = 25 

train_acc = []
val_acc = []
train_loss = []
val_loss = []

for i in range(n_epochs): 
    
    print(f"Epoch {i + 1}/{n_epochs}") 
    train_dataset = tf.data.Dataset.from_generator(
        lambda: generate_dataset(img_dir_lead, img_dir_trail, class_names_L, class_names_T, label_dict, image_size = (28,28), seed = seed),
        output_signature=(
            tf.TensorSpec(shape=(n_steps, 28, 28, 3), dtype=tf.float32),  # shape of x 
            tf.TensorSpec(shape=(n_steps, 1), dtype=tf.float32)  # shape of y 
        )
    ) 
    #for x, y in train_dataset.batch(32).map(img_preproc).map(flatten).take(1):
    #    pass
    #out = model(x)
    #print("EEEVAKUTAUIBNSANFIJASDIBG", model.evaluate(x, y))
    #print(out)
    #raise ValueError("STOP HERE")

    history = model.fit(train_dataset.shuffle(99999).batch(512).map(img_preproc).map(flatten), #  reshuffle_each_iteration=True
            validation_data=val_dataset.batch(512).map(img_preproc).map(flatten),
            callbacks=[checkpoint_callback]) # , epochs=25)
    
    train_acc.extend(history.history['accuracy'])
    val_acc.extend(history.history['val_accuracy'])
    train_loss.extend(history.history['loss'])
    val_loss.extend(history.history['val_loss'])

#print("\nWeights after training:")
#for i, layer_weights in enumerate(model.get_weights()):
#    print(f"Layer {i} weights:\n{layer_weights}\n")

loss, accuracy = model.evaluate(val_dataset.batch(512).map(img_preproc).map(flatten)) 
print(f"Accuracy after training: {accuracy}")
# Out:
# Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.0000e+00 - loss: 2.9802e-08
# 2024-10-18 10:58:29.666093: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# Accuracy before training: 0.0
# Epoch 1/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 19s 1s/step - accuracy: 0.6819 - loss: 0.1716Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy improved from -inf to 0.66832, saving model to /Users/denisekittelmann/Documents/Python/BiMoL/results/pcn/model_checkpoint_01_0.67.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6764 - loss: 0.1675 - val_accuracy: 0.3944 - val_loss: 2.9802e-08
# 2024-10-18 10:58:50.044548: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# Epoch 2/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 0.4686 - loss: 0.1678Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.66832
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.5087 - loss: 0.1661 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 3/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 0.6806 - loss: 0.1325Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.66832
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6680 - loss: 0.1647 - val_accuracy: 0.0222 - val_loss: 2.9802e-08
# 2024-10-18 10:59:09.081836: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# Epoch 4/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 11s 2s/step - accuracy: 0.4085 - loss: 0.1794Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.66832
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.4612 - loss: 0.1836 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 5/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 9s 1s/step - accuracy: 0.6819 - loss: -0.0386Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy improved from 0.66832 to 0.68193, saving model to /Users/denisekittelmann/Documents/Python/BiMoL/results/pcn/model_checkpoint_01_0.68.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - accuracy: 0.6819 - loss: 0.0732 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 6/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 0.6632 - loss: 0.1650Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6600 - loss: 0.1658 - val_accuracy: 0.4889 - val_loss: 2.9802e-08
# Epoch 7/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 0.4367 - loss: 0.1755Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.4019 - loss: 0.1747 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# 2024-10-18 10:59:52.434673: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# Epoch 8/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 0.6819 - loss: 0.1479Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.6819 - loss: 0.1482 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 9/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 0.5578 - loss: 0.1871Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.5191 - loss: 0.1841 - val_accuracy: 0.3333 - val_loss: 2.9802e-08
# Epoch 10/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 9s 1s/step - accuracy: 0.6711 - loss: 0.1636Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6732 - loss: 0.1234 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 11/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       4/Unknown 8s 909ms/step - accuracy: 0.6753 - loss: 0.1110Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6721 - loss: 0.0988 - val_accuracy: 0.1333 - val_loss: 2.9802e-08
# Epoch 12/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 0.4918 - loss: 0.1696Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.4725 - loss: 0.1697 - val_accuracy: 0.3833 - val_loss: 2.9802e-08
# Epoch 13/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 0.6819 - loss: 0.1024Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6819 - loss: 0.1207 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 14/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 0.6819 - loss: 0.1636Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6816 - loss: 0.1616 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 15/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 2.1701e-04 - loss: 0.1569Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 6.2526e-04 - loss: 0.1573 - val_accuracy: 0.0111 - val_loss: 2.9802e-08
# 2024-10-18 11:01:10.982558: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# Epoch 16/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 0.4748 - loss: 0.1858Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.4198 - loss: 0.1858 - val_accuracy: 0.2056 - val_loss: 2.9802e-08
# Epoch 17/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 0.4670 - loss: 0.1313Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.5084 - loss: 0.0705 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 18/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 0.6819 - loss: 0.1427Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.6819 - loss: 0.1483 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 19/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 0.6452 - loss: 0.1518Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.6054 - loss: 0.1401 - val_accuracy: 0.0000e+00 - val_loss: 2.9802e-08
# Epoch 20/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 8s 1s/step - accuracy: 0.0753 - loss: 0.1595    Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.1437 - loss: 0.1577 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 21/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 7s 1s/step - accuracy: 0.6819 - loss: 0.1673Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.6819 - loss: 0.1673 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 22/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 7s 1s/step - accuracy: 0.6819 - loss: 0.1576Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.6819 - loss: 0.1528 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 23/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 7s 1s/step - accuracy: 0.0031 - loss: 0.1600    Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.0177 - loss: 0.1596 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 24/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 7s 1s/step - accuracy: 0.6819 - loss: 0.0606Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.6819 - loss: 0.1056 - val_accuracy: 0.5000 - val_loss: 2.9802e-08
# Epoch 25/25
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#       3/Unknown 7s 1s/step - accuracy: 0.5664 - loss: 0.4206Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
#
# Epoch 1: accuracy did not improve from 0.68193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.4958 - loss: 0.3158 - val_accuracy: 0.0000e+00 - val_loss: 2.9802e-08
# Found 180 files belonging to 5 classes.
# Found 180 files belonging to 4 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 926ms/step - accuracy: 0.0000e+00 - loss: 2.9802e-08
# Accuracy after training: 0.0

# %%
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# define the model
model = PredictiveCodingNetwork([CustomDense(units=500, activation="tanh"),
                                 CustomDense(units=500, activation="tanh"),
                                 CustomDense(units=1, activation="sigmoid")],
                                vars=[1, 1, 1], # variances. This is super useless and in the code only the last variance is used
                                beta=0.1)

model.build([None, 2352]) 
model.compile(optimizer=tf.keras.optimizers.AdamW(),
              metrics= ["accuracy"],  # , [SequenceAccuracy], [frame_accuracy(i) for i in range(4)]
              loss="CategoricalCrossentropy",  # This is just a sham loss we need so model.evaluate doesn't throw an error. We don't use it.
              )

# evaluate accuracy and train model
loss, accuracy = model.evaluate(val_dataset.map(img_preproc).map(flatten))
print(f"Accuracy before training: {accuracy}")


train_dataset = tf.data.Dataset.from_generator(
    lambda: generate_dataset(img_dir_lead, img_dir_trail, class_names_L, class_names_T, label_dict, image_size = (28,28), seed = seed),
    output_signature=(
    tf.TensorSpec(shape=(n_steps, 28, 28, 3), dtype=tf.float32),  # shape of x 
    tf.TensorSpec(shape=(n_steps, 1), dtype=tf.float32)# shape of y 
    )
)    

train_dataset = train_dataset.shuffle(99999).batch(32).map(img_preproc).map(flatten).repeat()

model.fit(train_dataset,
          epochs = 3,
        #validation_data=val_dataset.batch(batch_size).map(img_preproc).map(flatten),
          callbacks=[checkpoint_callback]) # epochs=3
          #callbacks=[AccuracyPerSequence]) # ADD


loss, accuracy = model.evaluate(val_dataset.map(img_preproc).map(flatten))
print(f"Accuracy after training: {accuracy}")
# Out:
# Found 180 files belonging to 5 classes.
# /Users/denisekittelmann/miniconda3/envs/BiMo_3.9/lib/python3.9/site-packages/keras/src/losses/losses.py:27: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(4, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# Found 180 files belonging to 4 classes.
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: 3.2838e-08
# Accuracy before training: 0.0
# Epoch 1/3
# /Users/denisekittelmann/miniconda3/envs/BiMo_3.9/lib/python3.9/contextlib.py:137: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#      49/Unknown 5s 30ms/step - accuracy: 0.6200 - loss: 0.1918Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     100/Unknown 9s 52ms/step - accuracy: 0.6354 - loss: 0.1868Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     150/Unknown 13s 62ms/step - accuracy: 0.6377 - loss: 0.1816Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     197/Unknown 17s 67ms/step - accuracy: 0.6321 - loss: 0.1772Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     240/Unknown 20s 70ms/step - accuracy: 0.6281 - loss: 0.1750Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     275/Unknown 24s 73ms/step - accuracy: 0.6247 - loss: 0.1738Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     307/Unknown 27s 76ms/step - accuracy: 0.6210 - loss: 0.1723Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     358/Unknown 30s 75ms/step - accuracy: 0.6174 - loss: 0.1707Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     409/Unknown 34s 74ms/step - accuracy: 0.6136 - loss: 0.1701Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     460/Unknown 37s 74ms/step - accuracy: 0.6098 - loss: 0.1700Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     511/Unknown 41s 73ms/step - accuracy: 0.6076 - loss: 0.1701Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     562/Unknown 44s 73ms/step - accuracy: 0.6057 - loss: 0.1707Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     613/Unknown 48s 73ms/step - accuracy: 0.6043 - loss: 0.1719Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     664/Unknown 52s 73ms/step - accuracy: 0.6033 - loss: 0.1726Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     715/Unknown 56s 74ms/step - accuracy: 0.6025 - loss: 0.1731Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     766/Unknown 60s 74ms/step - accuracy: 0.6021 - loss: 0.1736Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     817/Unknown 64s 74ms/step - accuracy: 0.6020 - loss: 0.1739Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     868/Unknown 68s 74ms/step - accuracy: 0.6021 - loss: 0.1743Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     919/Unknown 71s 74ms/step - accuracy: 0.6024 - loss: 0.1746Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#     970/Unknown 75s 74ms/step - accuracy: 0.6029 - loss: 0.1748Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#    1021/Unknown 79s 74ms/step - accuracy: 0.6035 - loss: 0.1749Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#    1072/Unknown 83s 74ms/step - accuracy: 0.6042 - loss: 0.1750Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#    1123/Unknown 87s 74ms/step - accuracy: 0.6049 - loss: 0.1750Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#    1174/Unknown 91s 74ms/step - accuracy: 0.6057 - loss: 0.1749Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#    1225/Unknown 94s 74ms/step - accuracy: 0.6065 - loss: 0.1749Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#    1276/Unknown 98s 74ms/step - accuracy: 0.6073 - loss: 0.1747Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#    1327/Unknown 102s 74ms/step - accuracy: 0.6081 - loss: 0.1746Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#    1378/Unknown 105s 74ms/step - accuracy: 0.6089 - loss: 0.1745Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#    1429/Unknown 109s 74ms/step - accuracy: 0.6097 - loss: 0.1743Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#    1480/Unknown 113s 74ms/step - accuracy: 0.6104 - loss: 0.1742Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#    
- loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   58600/Unknown 4149s 71ms/step - accuracy: 0.6513 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   58651/Unknown 4153s 71ms/step - accuracy: 0.6513 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   58702/Unknown 4157s 71ms/step - accuracy: 0.6513 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   58753/Unknown 4160s 71ms/step - accuracy: 0.6513 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   58804/Unknown 4163s 71ms/step - accuracy: 0.6513 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   58855/Unknown 4167s 71ms/step - accuracy: 0.6513 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   58906/Unknown 4170s 71ms/step - accuracy: 0.6513 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   58957/Unknown 4173s 71ms/step - accuracy: 0.6513 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59008/Unknown 4176s 71ms/step - accuracy: 0.6514 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59059/Unknown 4179s 71ms/step - accuracy: 0.6514 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59110/Unknown 4182s 71ms/step - accuracy: 0.6514 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59161/Unknown 4185s 71ms/step - accuracy: 0.6514 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59212/Unknown 4188s 71ms/step - accuracy: 0.6514 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59263/Unknown 4191s 71ms/step - accuracy: 0.6514 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59314/Unknown 4194s 71ms/step - accuracy: 0.6514 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59365/Unknown 4197s 71ms/step - accuracy: 0.6514 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59416/Unknown 4200s 71ms/step - accuracy: 0.6514 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59467/Unknown 4204s 71ms/step - accuracy: 0.6514 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59518/Unknown 4207s 71ms/step - accuracy: 0.6515 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59569/Unknown 4210s 71ms/step - accuracy: 0.6515 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59620/Unknown 4213s 71ms/step - accuracy: 0.6515 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59671/Unknown 4216s 71ms/step - accuracy: 0.6515 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59722/Unknown 4219s 71ms/step - accuracy: 0.6515 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59773/Unknown 4222s 71ms/step - accuracy: 0.6515 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59824/Unknown 4225s 71ms/step - accuracy: 0.6515 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59875/Unknown 4228s 71ms/step - accuracy: 0.6515 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59926/Unknown 4231s 71ms/step - accuracy: 0.6515 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   59977/Unknown 4236s 71ms/step - accuracy: 0.6515 - loss: 0.1615Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   60028/Unknown 4242s 71ms/step - accuracy: 0.6516 - loss: 0.1616Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   60079/Unknown 4246s 71ms/step - accuracy: 0.6516 - loss: 0.1616Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   60130/Unknown 4250s 71ms/step - accuracy: 0.6516 - loss: 0.1616Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   60181/Unknown 4254s 71ms/step - accuracy: 0.6516 - loss: 0.1616Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   60232/Unknown 4258s 71ms/step - accuracy: 0.6516 - loss: 0.1616Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   60283/Unknown 4263s 71ms/step - accuracy: 0.6516 - loss: 0.1616Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
#   60334/Unknown 4267s 71ms/step - accuracy: 0.6516 - loss: 0.1616Found 1616 files belonging to 5 classes.
# Found 1616 files belonging to 4 classes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 29
#      19 train_dataset = tf.data.Dataset.from_generator(
#      20     lambda: generate_dataset(img_dir_lead, img_dir_trail, class_names_L, class_names_T, label_dict, image_size = (28,28), seed = seed),
#      21     output_signature=(
#    (...)
#      24     )
#      25 )
#      27 train_dataset = train_dataset.shuffle(99999).batch(32).map(img_preproc).map(flatten).repeat()
# ---> 29 model.fit(train_dataset,
#      30           epochs = 3,
#      31         #validation_data=val_dataset.batch(batch_size).map(img_preproc).map(flatten),
#      32           callbacks=[checkpoint_callback]) # epochs=3
#      33           #callbacks=[AccuracyPerSequence]) # ADD
#      36 loss, accuracy = model.evaluate(val_dataset.map(img_preproc).map(flatten))
#
# File ~/miniconda3/envs/BiMo_3.9/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/BiMo_3.9/lib/python3.9/site-packages/keras/src/backend/tensorflow/trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     logs = self._pythonify_logs(logs)
#     322     callbacks.on_train_batch_end(step, logs)
#
# File ~/miniconda3/envs/BiMo_3.9/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/BiMo_3.9/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/BiMo_3.9/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/miniconda3/envs/BiMo_3.9/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/miniconda3/envs/BiMo_3.9/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/BiMo_3.9/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/miniconda3/envs/BiMo_3.9/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/miniconda3/envs/BiMo_3.9/lib/python3.9/site-packages/tensorflow/python/eager/context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File ~/miniconda3/envs/BiMo_3.9/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
